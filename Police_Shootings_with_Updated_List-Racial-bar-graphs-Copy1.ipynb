# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
'load fatal police shootings data'
police = pd.read_csv('fatal-police-shootings-data.csv')
police
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4687  5147                 Michael Pinkerman  2019-10-30              shot
# 4688  5149                             TK TK  2019-10-30              shot
# 4689  5162            Billy Kongphouthakhoun  2019-10-30              shot
# 4690  5163                             TK TK  2019-10-30              shot
# 4691  5160                  Danny James Hall  2019-10-31              shot
# 4692  5161                             TK TK  2019-10-31              shot
# 4693  5150                     Benjamin Diaz  2019-11-01              shot
# 4694  5158                             TK TK  2019-11-01              shot
# 4695  5159              Luis Morales-Camacho  2019-11-01              shot
# 4696  5173              Luis Fino Nabarrette  2019-11-01              shot
# 4697  5155                     Michael Kifer  2019-11-02  shot and Tasered
# 4698  5157                         John Hale  2019-11-02              shot
# 4699  5153                             TK TK  2019-11-03              shot
# 4700  5154                    Michael Austin  2019-11-03              shot
# 4701  5151                             TK TK  2019-11-04              shot
# 4702  5172                 Matthew Rasmussen  2019-11-04              shot
# 4703  5174                   Daniel M. Munoz  2019-11-04              shot
# 4704  5175                             TK TK  2019-11-04              shot
# 4705  5167                     Maurice Brown  2019-11-05              shot
# 4706  5168                     Jay P. Messer  2019-11-05              shot
# 4707  5169                             TK TK  2019-11-05              shot
# 4708  5171              Christopher Alan Noe  2019-11-05  shot and Tasered
# 4709  5164                 Eddie Ray Maxwell  2019-11-06              shot
# 4710  5165               Corben Hunter Jones  2019-11-06              shot
# 4711  5166                             TK TK  2019-11-06              shot
# 4712  5170                  Treva Smutherman  2019-11-06              shot
# 4713  5176                Guy Thomas Barnard  2019-11-07              shot
# 4714  5177                             TK TK  2019-11-07              shot
# 4715  5178               Gerald Newton Allen  2019-11-07              shot
# 4716  5179                 Christopher Mills  2019-11-07              shot
#
#              armed   age gender race                city state  \
# 0              gun  53.0      M    A             Shelton    WA
# 1              gun  47.0      M    W               Aloha    OR
# 2          unarmed  23.0      M    H             Wichita    KS
# 3       toy weapon  32.0      M    W       San Francisco    CA
# 4         nail gun  39.0      M    H               Evans    CO
# 5              gun  18.0      M    W             Guthrie    OK
# 6              gun  22.0      M    H            Chandler    AZ
# 7              gun  35.0      M    W             Assaria    KS
# 8          unarmed  34.0      F    W          Burlington    IA
# 9       toy weapon  47.0      M    B           Knoxville    PA
# 10           knife  25.0      M    W            Stockton    CA
# 11             gun  31.0      M    B            Freeport    TX
# 12           knife  41.0      M    B            Columbus    OH
# 13             gun  30.0      M    W          Des Moines    IA
# 14             gun  37.0      M    B         New Orleans    LA
# 15             NaN  28.0      M    W             Huntley    MT
# 16          shovel  42.0      M    W      Salt Lake City    UT
# 17         unarmed  36.0      M    B              Strong    AR
# 18             gun  49.0      M    W            Syracuse    UT
# 19             gun  71.0      M    W             England    AR
# 20             gun  33.0      M    H             El Paso    TX
# 21             gun  39.0      M    W              Arcola    IL
# 22             gun  23.0      M    H          South Gate    CA
# 23             gun  29.0      M    H     North Las Vegas    NV
# 24             gun  34.0      M    W         Albuquerque    NM
# 25           knife  43.0      M    W          Jourdanton    TX
# 26             NaN  24.0      M    B            St. Paul    MN
# 27             NaN  29.0      M    W     Franklin County    MO
# 28             gun  34.0      M    B          Chesapeake    VA
# 29           knife  75.0      M    W          Old Bridge    NJ
# ...            ...   ...    ...  ...                 ...   ...
# 4687           gun   NaN      M    W                 Ona    WV
# 4688         knife   NaN      M  NaN            San Jose    CA
# 4689           gun   NaN      M    A              Fresno    CA
# 4690            ax   NaN      M  NaN           Lancaster    CA
# 4691           gun  34.0      M    W              Bascom    FL
# 4692    toy weapon   NaN      M  NaN            San Jose    CA
# 4693  sharp object  22.0      M    H          Alamogordo    NM
# 4694  undetermined   NaN      M  NaN        Adams County    CO
# 4695  undetermined  41.0      M    H             Orlando    FL
# 4696           gun  38.0      M    H              Odessa    TX
# 4697         sword  29.0      M    W          Vero Beach    FL
# 4698  undetermined  42.0      M    W              Dexter    KY
# 4699         knife  56.0      M  NaN            Parkland    WA
# 4700           gun  32.0      M    B             Phoenix    AZ
# 4701           gun   NaN      M  NaN        Sunland Park    NM
# 4702  sharp object  31.0      M    W            Glendale    AZ
# 4703           gun  21.0      M    H          Las Cruces    NM
# 4704           gun   NaN      M  NaN          Two Rivers    WI
# 4705           gun  48.0      M    B      East Cleveland    OH
# 4706           gun  58.0      M  NaN       Pettis County    MO
# 4707           gun   NaN      M  NaN                Leon    WI
# 4708         knife  45.0      M  NaN              Willis    TX
# 4709           gun  37.0      M    B           Tahlequah    OK
# 4710  undetermined  20.0      M    W           Henryetta    OK
# 4711           gun   NaN      M  NaN         San Antonio    TX
# 4712           gun  31.0      M    B        Fayetteville    NC
# 4713        BB gun  26.0      M  NaN           Wadsworth    OH
# 4714           gun   NaN      M  NaN          Louisville    KY
# 4715           gun  66.0      M  NaN             Conyers    GA
# 4716           gun  37.0      M  NaN  Ashtabula Township    OH
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# 5                       False        attack  Not fleeing        False
# 6                       False        attack          Car        False
# 7                       False        attack  Not fleeing        False
# 8                       False         other  Not fleeing         True
# 9                       False        attack  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 11                      False        attack  Not fleeing        False
# 12                       True         other  Not fleeing        False
# 13                      False        attack          Car        False
# 14                      False        attack         Foot         True
# 15                      False  undetermined  Not fleeing        False
# 16                      False        attack  Not fleeing         True
# 17                      False        attack  Not fleeing        False
# 18                      False        attack  Not fleeing         True
# 19                      False        attack  Not fleeing        False
# 20                      False        attack  Not fleeing        False
# 21                       True        attack  Not fleeing        False
# 22                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 24                      False        attack         Foot         True
# 25                       True         other  Not fleeing        False
# 26                      False        attack  Not fleeing        False
# 27                      False        attack  Not fleeing        False
# 28                       True        attack  Not fleeing        False
# 29                      False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 4687                    False        attack  Not fleeing        False
# 4688                    False         other  Not fleeing        False
# 4689                    False         other  Not fleeing        False
# 4690                    False         other  Not fleeing        False
# 4691                    False        attack          Car        False
# 4692                    False        attack  Not fleeing        False
# 4693                    False        attack          Car        False
# 4694                    False  undetermined          NaN        False
# 4695                    False        attack  Not fleeing        False
# 4696                    False        attack          Car        False
# 4697                    False        attack  Not fleeing        False
# 4698                    False        attack          NaN        False
# 4699                    False         other  Not fleeing        False
# 4700                    False        attack  Not fleeing        False
# 4701                    False        attack         Foot        False
# 4702                     True        attack  Not fleeing        False
# 4703                    False        attack          NaN        False
# 4704                    False         other  Not fleeing        False
# 4705                    False        attack  Not fleeing         True
# 4706                    False        attack  Not fleeing        False
# 4707                    False         other  Not fleeing        False
# 4708                    False         other          Car        False
# 4709                    False        attack  Not fleeing        False
# 4710                    False  undetermined          NaN        False
# 4711                    False         other          NaN        False
# 4712                    False        attack  Not fleeing        False
# 4713                    False        attack          NaN        False
# 4714                    False        attack          NaN        False
# 4715                    False        attack  Not fleeing        False
# 4716                    False         other  Not fleeing        False
#
# [4717 rows x 14 columns]

# %%
'loading population data'
city_population = pd.read_csv('CityPopulation2000.csv', encoding = "ISO-8859-1")
city_population
# Out:
#       Geographic Area                               City     Population
# 0                  AL                         Abanda CDP            192
# 1                  AL                     Abbeville city           2688
# 2                  AL                    Adamsville city           4522
# 3                  AL                       Addison town            758
# 4                  AL                         Akron town            356
# 5                  AL                     Alabaster city          30352
# 6                  AL                   Albertville city          21160
# 7                  AL                Alexander City city          14875
# 8                  AL                     Alexandria CDP           3917
# 9                  AL                    Aliceville city           2486
# 10                 AL                       Allgood town            622
# 11                 AL                       Altoona town            933
# 12                 AL                     Andalusia city           9015
# 13                 AL                      Anderson town            282
# 14                 AL                      Anniston city          23106
# 15                 AL                          Arab city           8050
# 16                 AL                       Ardmore town           1194
# 17                 AL                          Argo town           4071
# 18                 AL                        Ariton town            764
# 19                 AL                         Arley town            357
# 20                 AL                       Ashford town           2148
# 21                 AL                       Ashland town           2037
# 22                 AL                      Ashville city           2212
# 23                 AL                        Athens city          21897
# 24                 AL                        Atmore city          10194
# 25                 AL                       Attalla city           6048
# 26                 AL                        Auburn city  53380(r38811)
# 27                 AL                  Autaugaville town            870
# 28                 AL                          Avon town            543
# 29                 AL                           Axis CDP            757
# ...               ...                                ...            ...
# 29493     Puerto Rico               San Isidro comunidad           6828
# 29494     Puerto Rico                 San José comunidad           2900
# 29495     Puerto Rico               San Juan zona urbana         381931
# 29496     Puerto Rico            San Lorenzo zona urbana           8037
# 29497     Puerto Rico          San Sebastián zona urbana           9622
# 29498     Puerto Rico            Santa Bárbara comunidad           4622
# 29499     Puerto Rico              Santa Clara comunidad            982
# 29500     Puerto Rico           Santa Isabel zona urbana           5976
# 29501     Puerto Rico            Santo Domingo comunidad           3156
# 29502     Puerto Rico                   Stella comunidad           1088
# 29503     Puerto Rico                   Suárez comunidad           1931
# 29504     Puerto Rico                 Tallaboa comunidad            925
# 29505     Puerto Rico            Tallaboa Alta comunidad           1816
# 29506     Puerto Rico                    Tibes comunidad            362
# 29507     Puerto Rico                Tiburones comunidad           1616
# 29508     Puerto Rico  Tierras Nuevas Poniente comunidad           3228
# 29509     Puerto Rico               Toa Alta zona urbana           3713
# 29510     Puerto Rico               Toa Baja zona urbana           1513
# 29511     Puerto Rico          Trujillo Alto zona urbana          48437
# 29512     Puerto Rico                 Utuado zona urbana           8397
# 29513     Puerto Rico                    Vayas comunidad            528
# 29514     Puerto Rico                  Vázquez comunidad           1890
# 29515     Puerto Rico              Vega Alta zona urbana          10266
# 29516     Puerto Rico              Vega Baja zona urbana          25905
# 29517     Puerto Rico                  Vieques comunidad           3316
# 29518     Puerto Rico                Vieques zona urbana           1938
# 29519     Puerto Rico               Villalba zona urbana           3384
# 29520     Puerto Rico                Yabucoa zona urbana           6047
# 29521     Puerto Rico                  Yauco zona urbana          17186
# 29522     Puerto Rico                   Yaurel comunidad           1050
#
# [29523 rows x 3 columns]

# %%
'make a list of city populations'
city_pop_lst=[]
for i in range(len(city_population)):
    city_pop_lst.append([city_population['City'][i],city_population['Population'][i],city_population['Geographic Area'][i]])
print(len(city_pop_lst))

'taking care of division by zero error that could pop up'
city_pop_lst[25325][1]=1#the population of this used to be 0...
city_pop_lst[25325]

'taking care of division by zero that could pop up'
city_pop_lst[3331][1]=1#the population of this used to be 0...
city_pop_lst[3331]

city_pop_lst
# Out:
# 29523
# [['Abanda CDP', '192', 'AL'],
#  ['Abbeville city', '2688', 'AL'],
#  ['Adamsville city', '4522', 'AL'],
#  ['Addison town', '758', 'AL'],
#  ['Akron town', '356', 'AL'],
#  ['Alabaster city', '30352', 'AL'],
#  ['Albertville city', '21160', 'AL'],
#  ['Alexander City city', '14875', 'AL'],
#  ['Alexandria CDP', '3917', 'AL'],
#  ['Aliceville city', '2486', 'AL'],
#  ['Allgood town', '622', 'AL'],
#  ['Altoona town', '933', 'AL'],
#  ['Andalusia city', '9015', 'AL'],
#  ['Anderson town', '282', 'AL'],
#  ['Anniston city', '23106', 'AL'],
#  ['Arab city', '8050', 'AL'],
#  ['Ardmore town', '1194', 'AL'],
#  ['Argo town', '4071', 'AL'],
#  ['Ariton town', '764', 'AL'],
#  ['Arley town', '357', 'AL'],
#  ['Ashford town', '2148', 'AL'],
#  ['Ashland town', '2037', 'AL'],
#  ['Ashville city', '2212', 'AL'],
#  ['Athens city', '21897', 'AL'],
#  ['Atmore city', '10194', 'AL'],
#  ['Attalla city', '6048', 'AL'],
#  ['Auburn city', '53380(r38811)', 'AL'],
#  ['Autaugaville town', '870', 'AL'],
#  ['Avon town', '543', 'AL'],
#  ['Axis CDP', '757', 'AL'],
#  ['Babbie town', '603', 'AL'],
#  ['Baileyton town', '610', 'AL'],
#  ['Bakerhill town', '279', 'AL'],
#  ['Ballplay CDP', '1580', 'AL'],
#  ['Banks town', '179', 'AL'],
#  ['Bay Minette city', '8044', 'AL'],
#  ['Bayou La Batre city', '2558', 'AL'],
#  ['Bear Creek town', '1070', 'AL'],
#  ['Beatrice town', '301', 'AL'],
#  ['Beaverton town', '201', 'AL'],
#  ['Belgreen CDP', '129', 'AL'],
#  ['Belk town', '215', 'AL'],
#  ['Bellamy CDP', '543', 'AL'],
#  ['Belle Fontaine CDP', '608', 'AL'],
#  ['Benton town', '49', 'AL'],
#  ['Berry town', '1148', 'AL'],
#  ['Bessemer city', '27456', 'AL'],
#  ['Billingsley town', '144', 'AL'],
#  ['Birmingham city', '212237(r38812)', 'AL'],
#  ['Black town', '207', 'AL'],
#  ['Blountsville town', '1684', 'AL'],
#  ['Blue Ridge CDP', '1341', 'AL'],
#  ['Blue Springs town', '96', 'AL'],
#  ['Boaz city', '9551', 'AL'],
#  ['Boligee town', '328', 'AL'],
#  ['Bon Air town', '116', 'AL'],
#  ['Boykin CDP', '275', 'AL'],
#  ['Brantley town', '809', 'AL'],
#  ['Brantleyville CDP', '884', 'AL'],
#  ['Brent city', '4947', 'AL'],
#  ['Brewton city', '5408', 'AL'],
#  ['Bridgeport city', '2418', 'AL'],
#  ['Brighton city', '2945', 'AL'],
#  ['Brilliant town', '900', 'AL'],
#  ['Bristow Cove CDP', '683', 'AL'],
#  ['Brook Highland CDP', '6746', 'AL'],
#  ['Brookside town', '1363', 'AL'],
#  ['Brookwood town', '1828', 'AL'],
#  ['Broomtown CDP', '182', 'AL'],
#  ['Brundidge city', '2076', 'AL'],
#  ['Bucks CDP', '32', 'AL'],
#  ['Butler town', '1894', 'AL'],
#  ['Calera city', '11620', 'AL'],
#  ['Calvert CDP', '277', 'AL'],
#  ['Camden city', '2020', 'AL'],
#  ['Camp Hill town', '1014', 'AL'],
#  ['Carbon Hill city', '2021', 'AL'],
#  ['Cardiff town', '55', 'AL'],
#  ['Carlisle-Rockledge CDP', '2137', 'AL'],
#  ['Carlton CDP', '65', 'AL'],
#  ['Carolina town', '297', 'AL'],
#  ['Carrollton town', '1019', 'AL'],
#  ['Castleberry town', '583', 'AL'],
#  ['Catherine CDP', '22', 'AL'],
#  ['Cedar Bluff town', '1820', 'AL'],
#  ['Center Point city', '16921', 'AL'],
#  ['Centre city', '3489', 'AL'],
#  ['Centreville city', '2778', 'AL'],
#  ['Chatom town', '1288', 'AL'],
#  ['Chelsea city', '10183', 'AL'],
#  ['Cherokee town', '1048', 'AL'],
#  ['Chickasaw city', '6106', 'AL'],
#  ['Childersburg city', '5175', 'AL'],
#  ['Choccolocco CDP', '2804', 'AL'],
#  ['Chunchula CDP', '210', 'AL'],
#  ['Citronelle city', '3905', 'AL'],
#  ['Clanton city', '8619', 'AL'],
#  ['Clay city', '9708', 'AL'],
#  ['Clayhatchee town', '589', 'AL'],
#  ['Clayton town', '3008', 'AL'],
#  ['Cleveland town', '1303', 'AL'],
#  ['Clio city', '1399', 'AL'],
#  ['Coaling town', '1657', 'AL'],
#  ['Coats Bend CDP', '1394', 'AL'],
#  ['Coffee Springs town', '228', 'AL'],
#  ['Coffeeville town', '352', 'AL'],
#  ['Coker town', '979', 'AL'],
#  ['Collinsville town', '1983', 'AL'],
#  ['Colony town', '268', 'AL'],
#  ['Columbia town', '740', 'AL'],
#  ['Columbiana city', '4197', 'AL'],
#  ['Concord CDP', '1837', 'AL'],
#  ['Coosada town', '1224', 'AL'],
#  ['Cordova city', '2095', 'AL'],
#  ['Cottonwood town', '1289', 'AL'],
#  ['County Line town', '258', 'AL'],
#  ['Courtland town', '609', 'AL'],
#  ['Cowarts town', '1871', 'AL'],
#  ['Creola city', '1926', 'AL'],
#  ['Crossville town', '1862', 'AL'],
#  ['Cuba town', '346', 'AL'],
#  ['Cullman city', '14775', 'AL'],
#  ['Cullomburg CDP', '171', 'AL'],
#  ['Cusseta town', '123', 'AL'],
#  ['Dadeville city', '3230', 'AL'],
#  ['Daleville city', '5295', 'AL'],
#  ['Daphne city', '21570', 'AL'],
#  ['Dauphin Island town', '1238', 'AL'],
#  ['Daviston town', '214', 'AL'],
#  ['Dayton town', '52', 'AL'],
#  ['Deatsville town', '1154', 'AL'],
#  ['Decatur city', '55683', 'AL'],
#  ['Deer Park CDP', '188', 'AL'],
#  ['Delta CDP', '197', 'AL'],
#  ['Demopolis city', '7483', 'AL'],
#  ['Detroit town', '237', 'AL'],
#  ['Dodge City town', '593', 'AL'],
#  ['Dora city', '2025', 'AL'],
#  ['Dothan city', '65496', 'AL'],
#  ['Double Springs town', '1083', 'AL'],
#  ['Douglas town', '744', 'AL'],
#  ['Dozier town', '329', 'AL'],
#  ['Dunnavant CDP', '981', 'AL'],
#  ['Dutton town', '315', 'AL'],
#  ['East Brewton city', '2478', 'AL'],
#  ['East Point CDP', '201', 'AL'],
#  ['Eclectic town', '1001', 'AL'],
#  ['Edgewater CDP', '883', 'AL'],
#  ['Edwardsville town', '202', 'AL'],
#  ['Egypt CDP', '932', 'AL'],
#  ['Elba city', '3940', 'AL'],
#  ['Elberta town', '1498', 'AL'],
#  ['Eldridge town', '130', 'AL'],
#  ['Elkmont town', '434', 'AL'],
#  ['Elmore town', '1262', 'AL'],
#  ['Emelle town', '53', 'AL'],
#  ['Emerald Mountain CDP', '2561', 'AL'],
#  ['Enterprise city', '26562', 'AL'],
#  ['Epes town', '192', 'AL'],
#  ['Ethelsville town', '81', 'AL'],
#  ['Eufaula city', '13137', 'AL'],
#  ['Eunola CDP', '243', 'AL'],
#  ['Eutaw town', '2934', 'AL'],
#  ['Eva town', '519', 'AL'],
#  ['Evergreen city', '3944', 'AL'],
#  ['Excel town', '723', 'AL'],
#  ['Fairfield city', '11117', 'AL'],
#  ['Fairford CDP', '186', 'AL'],
#  ['Fairhope city', '15326', 'AL'],
#  ['Fairview town', '446', 'AL'],
#  ['Falkville town', '1279', 'AL'],
#  ['Faunsdale town', '98', 'AL'],
#  ['Fayette city', '4619', 'AL'],
#  ['Fayetteville CDP', '1284', 'AL'],
#  ['Fitzpatrick CDP', '83', 'AL'],
#  ['Five Points town', '141', 'AL'],
#  ['Flomaton town', '1440', 'AL'],
#  ['Florala town', '1980', 'AL'],
#  ['Florence city', '39319', 'AL'],
#  ['Foley city', '14618', 'AL'],
#  ['Forestdale CDP', '10162', 'AL'],
#  ['Forkland town', '649', 'AL'],
#  ['Fort Deposit town', '1344', 'AL'],
#  ['Fort Payne city', '14012', 'AL'],
#  ['Fort Rucker CDP', '4636', 'AL'],
#  ['Franklin town', '149', 'AL'],
#  ['Fredonia CDP', '199', 'AL'],
#  ['Frisco City town', '1309', 'AL'],
#  ['Fruitdale CDP', '185', 'AL'],
#  ['Fruithurst town', '284', 'AL'],
#  ['Fulton town', '272', 'AL'],
#  ['Fultondale city', '8380', 'AL'],
#  ['Fyffe town', '1018', 'AL'],
#  ['Gadsden city', '36856', 'AL'],
#  ['Gainesville town', '208', 'AL'],
#  ['Gallant CDP', '855', 'AL'],
#  ['Gantt town', '222', 'AL'],
#  ['Garden City town', '492', 'AL'],
#  ['Gardendale city', '13893', 'AL'],
#  ['Gaylesville town', '144', 'AL'],
#  ['Geiger town', '170', 'AL'],
#  ['Geneva city', '4452', 'AL'],
#  ['Georgiana town', '1738', 'AL'],
#  ['Geraldine town', '896', 'AL'],
#  ['Gilbertown town', '215', 'AL'],
#  ['Glen Allen town', '510', 'AL'],
#  ['Glencoe city', '5160', 'AL'],
#  ['Glenwood town', '187', 'AL'],
#  ['Goldville town', '55', 'AL'],
#  ['Good Hope town', '2264', 'AL'],
#  ['Goodwater town', '1475', 'AL'],
#  ['Gordo town', '1750', 'AL'],
#  ['Gordon town', '332', 'AL'],
#  ['Gordonville town', '326', 'AL'],
#  ['Goshen town', '266', 'AL'],
#  ['Graham CDP', '211', 'AL'],
#  ['Grand Bay CDP', '3672', 'AL'],
#  ['Grant town', '896', 'AL'],
#  ['Grayson Valley CDP', '5736', 'AL'],
#  ['Graysville city', '2165', 'AL'],
#  ['Greensboro city', '2497', 'AL'],
#  ['Greenville city', '8135', 'AL'],
#  ['Grimes town', '558', 'AL'],
#  ['Grove Hill town', '1570', 'AL'],
#  ['Guin city', '2376', 'AL'],
#  ['Gulfcrest CDP', '161', 'AL'],
#  ['Gulf Shores city', '9741', 'AL'],
#  ['Guntersville city', '8197', 'AL'],
#  ['Gurley town', '801', 'AL'],
#  ['Gu-Win town', '176', 'AL'],
#  ['Hackleburg town', '1516', 'AL'],
#  ['Hackneyville CDP', '347', 'AL'],
#  ['Haleburg town', '103', 'AL'],
#  ['Haleyville city', '4173', 'AL'],
#  ['Hamilton city', '6885', 'AL'],
#  ['Hammondville town', '488', 'AL'],
#  ['Hanceville city', '2982(r38813)', 'AL'],
#  ['Harpersville town', '1637', 'AL'],
#  ['Hartford city', '2624', 'AL'],
#  ['Hartselle city', '14255', 'AL'],
#  ['Harvest CDP', '5281', 'AL'],
#  ['Hatton CDP', '261', 'AL'],
#  ['Hayden town', '444', 'AL'],
#  ['Hayneville town', '932', 'AL'],
#  ['Hazel Green CDP', '3630', 'AL'],
#  ['Headland city', '4510', 'AL'],
#  ['Heath town', '254', 'AL'],
#  ['Heflin city', '3480', 'AL'],
#  ['Helena city', '16793', 'AL'],
#  ['Henagar city', '2344', 'AL'],
#  ['Highland Lake town', '412', 'AL'],
#  ['Highland Lakes CDP', '3926', 'AL'],
#  ['Hillsboro town', '552', 'AL'],
#  ['Hissop CDP', '658', 'AL'],
#  ['Hobson CDP', '126', 'AL'],
#  ['Hobson City town', '771', 'AL'],
#  ['Hodges town', '288', 'AL'],
#  ['Hokes Bluff city', '4286', 'AL'],
#  ['Hollins CDP', '545', 'AL'],
#  ['Hollis Crossroads CDP', '608', 'AL'],
#  ['Holly Pond town', '798', 'AL'],
#  ['Hollywood town', '1000', 'AL'],
#  ['Holt CDP', '3638', 'AL'],
#  ['Holtville CDP', '4096', 'AL'],
#  ['Homewood city', '25167', 'AL'],
#  ['Hoover city', '81619', 'AL'],
#  ['Horn Hill town', '228', 'AL'],
#  ['Hueytown city', '16105', 'AL'],
#  ['Huguley CDP', '2540', 'AL'],
#  ['Huntsville city', '180105', 'AL'],
#  ['Hurtsboro town', '553', 'AL'],
#  ['Hytop town', '354', 'AL'],
#  ['Ider town', '723', 'AL'],
#  ['Indian Springs Village city', '2363', 'AL'],
#  ['Irondale city', '12349', 'AL'],
#  ['Ivalee CDP', '879', 'AL'],
#  ['Jackson city', '5228', 'AL'],
#  ["Jacksons' Gap town", '828', 'AL'],
#  ['Jacksonville city', '12548', 'AL'],
#  ['Jasper city', '14352', 'AL'],
#  ['Jemison city', '2585', 'AL'],
#  ['Joppa CDP', '501', 'AL'],
#  ['Kansas town', '226', 'AL'],
#  ['Kellyton town', '217', 'AL'],
#  ['Kennedy town', '447', 'AL'],
#  ['Killen town', '1108', 'AL'],
#  ['Kimberly town', '2711', 'AL'],
#  ['Kinsey town', '2198', 'AL'],
#  ['Kinston town', '540', 'AL'],
#  ['Ladonia CDP', '3142', 'AL'],
#  ['La Fayette city', '3003', 'AL'],
#  ['Lakeview town', '143', 'AL'],
#  ['Lake View town', '1943', 'AL'],
#  ['Lanett city', '6468', 'AL'],
#  ['Langston town', '270', 'AL'],
#  ['Leeds city', '11773', 'AL'],
#  ['Leesburg town', '1027', 'AL'],
#  ['Leighton town', '729', 'AL'],
#  ['Leroy CDP', '911', 'AL'],
#  ['Lester town', '111', 'AL'],
#  ['Level Plains town', '2085', 'AL'],
#  ['Lexington town', '735', 'AL'],
#  ['Libertyville town', '117', 'AL'],
#  ['Lincoln city', '6266', 'AL'],
#  ['Linden city', '2123', 'AL'],
#  ['Lineville city', '2395', 'AL'],
#  ['Lipscomb city', '2210', 'AL'],
#  ['Lisman town', '539', 'AL'],
#  ['Littleville town', '1011', 'AL'],
#  ['Livingston city', '3485', 'AL'],
#  ['Loachapoka town', '180', 'AL'],
#  ['Lockhart town', '516', 'AL'],
#  ['Locust Fork town', '1186', 'AL'],
#  ['Lookout Mountain CDP', '1621', 'AL'],
#  ['Louisville town', '519', 'AL'],
#  ['Lowndesboro town', '115', 'AL'],
#  ['Loxley town', '1632', 'AL'],
#  ['Luverne city', '2800', 'AL'],
#  ['Lynn town', '659', 'AL'],
#  ['McDonald Chapel CDP', '717', 'AL'],
#  ['Macedonia CDP', '292', 'AL'],
#  ['McIntosh town', '238', 'AL'],
#  ['McKenzie town', '530', 'AL'],
#  ['McMullen town', '10', 'AL'],
#  ['Madison city', '42938', 'AL'],
#  ['Madrid town', '350', 'AL'],
#  ['Magnolia Springs town', '723', 'AL'],
#  ['Malcolm CDP', '187', 'AL'],
#  ['Malvern town', '1448', 'AL'],
#  ['Maplesville town', '708', 'AL'],
#  ['Marbury CDP', '1418', 'AL'],
#  ['Margaret town', '4428', 'AL'],
#  ['Marion city', '3686', 'AL'],
#  ['Maytown town', '385', 'AL'],
#  ['Meadowbrook CDP', '8769', 'AL'],
#  ['Megargel CDP', '62', 'AL'],
#  ['Memphis town', '29', 'AL'],
#  ['Mentone town', '360', 'AL'],
#  ['Meridianville CDP', '6021', 'AL'],
#  ['Midfield city', '5365', 'AL'],
#  ['Midland City town', '2344', 'AL'],
#  ['Midway town', '499', 'AL'],
#  ['Mignon CDP', '1284', 'AL'],
#  ['Millbrook city', '14640', 'AL'],
#  ['Millerville CDP', '278', 'AL'],
#  ['Millport town', '1049', 'AL'],
#  ['Millry town', '546', 'AL'],
#  ['Minor CDP', '1094', 'AL'],
#  ['Mobile city', '195111(r38814)', 'AL'],
#  ['Monroeville city', '6519', 'AL'],
#  ['Montevallo city', '6323', 'AL'],
#  ['Montgomery city', '205764', 'AL'],
#  ['Moody city', '11726', 'AL'],
#  ['Moores Mill CDP', '5682', 'AL'],
#  ['Mooresville town', '53', 'AL'],
#  ['Morris town', '1859', 'AL'],
#  ['Morrison Crossroads CDP', '219', 'AL'],
#  ['Mosses town', '1029', 'AL'],
#  ['Moulton city', '3471', 'AL'],
#  ['Moundville town', '2427', 'AL'],
#  ['Mountain Brook city', '20413(r38815)', 'AL'],
#  ['Mount Olive CDP (Coosa County)', '371', 'AL'],
#  ['Mount Olive CDP (Jefferson County)', '4079', 'AL'],
#  ['Mount Vernon town', '1574', 'AL'],
#  ['Movico CDP', '305', 'AL'],
#  ['Mulga town', '836', 'AL'],
#  ['Munford town', '1292', 'AL'],
#  ['Muscle Shoals city', '13146', 'AL'],
#  ['Myrtlewood town', '130', 'AL'],
#  ['Nanafalia CDP', '94', 'AL'],
#  ['Nances Creek CDP', '407', 'AL'],
#  ['Napier Field town', '354', 'AL'],
#  ['Natural Bridge town', '37', 'AL'],
#  ['Nauvoo town', '221', 'AL'],
#  ['Nectar town', '345', 'AL'],
#  ['Needham town', '94', 'AL'],
#  ['Newbern town', '186', 'AL'],
#  ['New Brockton town', '1146', 'AL'],
#  ['New Hope city', '2810', 'AL'],
#  ['New Market CDP', '1597', 'AL'],
#  ['New Site town', '773', 'AL'],
#  ['Newton town', '1511', 'AL'],
#  ['New Union CDP', '955', 'AL'],
#  ['Newville town', '539', 'AL'],
#  ['North Courtland town', '632', 'AL'],
#  ['North Johns town', '145', 'AL'],
#  ['Northport city', '23330', 'AL'],
#  ['Notasulga town', '965', 'AL'],
#  ['Oak Grove town', '528', 'AL'],
#  ['Oak Hill town', '26', 'AL'],
#  ['Oakman town', '789', 'AL'],
#  ['Odenville town', '3585', 'AL'],
#  ['Ohatchee town', '1170', 'AL'],
#  ['Oneonta city', '6567', 'AL'],
#  ['Onycha town', '184', 'AL'],
#  ['Opelika city', '26477(r38816)', 'AL'],
#  ['Opp city', '6659', 'AL'],
#  ['Orange Beach city', '5441', 'AL'],
#  ['Orrville town', '204', 'AL'],
#  ['Our Town CDP', '641', 'AL'],
#  ['Owens Cross Roads town', '1521', 'AL'],
#  ['Oxford city', '21348', 'AL'],
#  ['Ozark city', '14907', 'AL'],
#  ['Paint Rock town', '210', 'AL'],
#  ['Panola CDP', '144', 'AL'],
#  ['Parrish town', '982', 'AL'],
#  ['Pelham city', '21352', 'AL'],
#  ['Pell City city', '12695', 'AL'],
#  ['Pennington town', '221', 'AL'],
#  ['Penton CDP', '201', 'AL'],
#  ['Perdido Beach town', '581', 'AL'],
#  ['Peterman CDP', '89', 'AL'],
#  ['Petrey town', '58', 'AL'],
#  ['Phenix City city', '32822', 'AL'],
#  ['Phil Campbell town', '1148', 'AL'],
#  ['Pickensville town', '608', 'AL'],
#  ['Piedmont city', '4878', 'AL'],
#  ['Pike Road town', '5406', 'AL'],
#  ['Pinckard town', '647', 'AL'],
#  ['Pine Apple town', '132', 'AL'],
#  ['Pine Hill town', '975', 'AL'],
#  ['Pine Level CDP', '4183', 'AL'],
#  ['Pine Ridge town', '282', 'AL'],
#  ['Pinson city', '7163', 'AL'],
#  ['Pisgah town', '722', 'AL'],
#  ['Pleasant Grove city', '10110', 'AL'],
#  ['Pleasant Groves town', '420', 'AL'],
#  ['Point Clear CDP', '2125', 'AL'],
#  ['Pollard town', '137', 'AL'],
#  ['Powell town', '955', 'AL'],
#  ['Prattville city', '33960', 'AL'],
#  ['Priceville town', '2658', 'AL'],
#  ['Prichard city', '22659', 'AL'],
#  ['Providence town', '223', 'AL'],
#  ['Putnam CDP', '193', 'AL'],
#  ['Ragland town', '1639', 'AL'],
#  ['Rainbow City city', '9602', 'AL'],
#  ['Rainsville city', '4948', 'AL'],
#  ['Ranburne town', '409', 'AL'],
#  ['Ray CDP', '443', 'AL'],
#  ['Red Bay city', '3158', 'AL'],
#  ['Redland CDP', '3736', 'AL'],
#  ['Red Level town', '487', 'AL'],
#  ['Redstone Arsenal CDP', '1946', 'AL'],
#  ['Reece City town', '653', 'AL'],
#  ['Reeltown CDP', '766', 'AL'],
#  ['Reform town', '1702', 'AL'],
#  ['Rehobeth town', '1297', 'AL'],
#  ['Repton town', '282', 'AL'],
#  ['Ridgeville town', '112', 'AL'],
#  ['River Falls town', '526', 'AL'],
#  ['Riverside town', '2208', 'AL'],
#  ['Riverview town', '184', 'AL'],
#  ['Roanoke city', '6074', 'AL'],
#  ['Robertsdale city', '5276', 'AL'],
#  ['Rock Creek CDP', '1456', 'AL'],
#  ['Rockford town', '477', 'AL'],
#  ['Rock Mills CDP', '600', 'AL'],
#  ['Rockville CDP', '43', 'AL'],
#  ['Rogersville town', '1257', 'AL'],
#  ['Rosa town', '316', 'AL'],
#  ['Russellville city', '9830', 'AL'],
#  ['Rutledge town', '467', 'AL'],
#  ['St. Florian town', '413', 'AL'],
#  ['St. Stephens CDP', '495', 'AL'],
#  ['Saks CDP', '10744', 'AL'],
#  ['Samson city', '1940', 'AL'],
#  ['Sand Rock town', '560', 'AL'],
#  ['Sanford town', '241', 'AL'],
#  ['Saraland city', '13405', 'AL'],
#  ['Sardis City town', '1704', 'AL'],
#  ['Satsuma city', '6168', 'AL'],
#  ['Scottsboro city', '14770', 'AL'],
#  ['Section town', '770', 'AL'],
#  ['Selma city', '20756', 'AL'],
#  ['Selmont-West Selmont CDP', '2671', 'AL'],
#  ['Sheffield city', '9039', 'AL'],
#  ['Shelby CDP', '1044', 'AL'],
#  ['Shiloh town', '274', 'AL'],
#  ['Shoal Creek CDP', '1400', 'AL'],
#  ['Shorter town', '474', 'AL'],
#  ['Silas town', '452', 'AL'],
#  ['Silverhill town', '706', 'AL'],
#  ['Sims Chapel CDP', '153', 'AL'],
#  ['Sipsey town', '437', 'AL'],
#  ['Skyline town', '851', 'AL'],
#  ['Slocomb city', '1980', 'AL'],
#  ['Smiths Station city', '4926', 'AL'],
#  ['Smoke Rise CDP', '1825', 'AL'],
#  ['Snead town', '835', 'AL'],
#  ['Somerville town', '724', 'AL'],
#  ['Southside city', '8412', 'AL'],
#  ['South Vinemont town', '749', 'AL'],
#  ['Spanish Fort city', '6798', 'AL'],
#  ['Spring Garden CDP', '238', 'AL'],
#  ['Springville city', '4080', 'AL'],
#  ['Spruce Pine CDP', '222', 'AL'],
#  ['Standing Rock CDP', '168', 'AL'],
#  ['Steele town', '1043', 'AL'],
#  ['Sterrett CDP', '712', 'AL'],
#  ['Stevenson city', '2046', 'AL'],
#  ['Stewartville CDP', '1767', 'AL'],
#  ['Sulligent city', '1927', 'AL'],
#  ['Sumiton city', '2520', 'AL'],
#  ['Summerdale town', '862', 'AL'],
#  ['Susan Moore town', '763', 'AL'],
#  ['Sweet Water town', '258', 'AL'],
#  ['Sylacauga city', '12749', 'AL'],
#  ['Sylvania town', '1837', 'AL'],
#  ['Sylvan Springs town', '1542', 'AL'],
#  ['Talladega city', '15676(r38817)', 'AL'],
#  ['Talladega Springs town', '166', 'AL'],
#  ['Tallassee city', '4819', 'AL'],
#  ['Tarrant city', '6397(r38818)', 'AL'],
#  ['Taylor town', '2375', 'AL'],
#  ['Theodore CDP', '6130', 'AL'],
#  ['Thomaston town', '417', 'AL'],
#  ['Thomasville city', '4209', 'AL'],
#  ['Thorsby town', '1980', 'AL'],
#  ['Tibbie CDP', '41', 'AL'],
#  ['Tidmore Bend CDP', '1245', 'AL'],
#  ['Tillmans Corner CDP', '17398', 'AL'],
#  ['Town Creek town', '1100', 'AL'],
#  ['Toxey town', '137', 'AL'],
#  ['Trafford town', '646', 'AL'],
#  ['Triana town', '496', 'AL'],
#  ['Trinity town', '2095', 'AL'],
#  ['Troy city', '18033', 'AL'],
#  ['Trussville city', '19933(r38819)', 'AL'],
#  ['Tuscaloosa city', '90468', 'AL'],
#  ['Tuscumbia city', '8423', 'AL'],
#  ['Tuskegee city', '9865(r38820)', 'AL'],
#  ['Twin town', '399', 'AL'],
#  ['Underwood-Petersville CDP', '3247', 'AL'],
#  ['Union town', '237', 'AL'],
#  ['Union Grove town', '77', 'AL'],
#  ['Union Springs city', '3980', 'AL'],
#  ['Uniontown town', '1775', 'AL'],
#  ['Uriah CDP', '294', 'AL'],
#  ['Valley city', '9524', 'AL'],
#  ['Valley Grande city', '4020', 'AL'],
#  ['Valley Head town', '558', 'AL'],
#  ['Vance town', '1529', 'AL'],
#  ['Vandiver CDP', '1135', 'AL'],
#  ['Vernon city', '2000', 'AL'],
#  ['Vestavia Hills city', '34033(r38821)', 'AL'],
#  ['Vina town', '358', 'AL'],
#  ['Vincent town', '1988(r38822)', 'AL'],
#  ['Vinegar Bend CDP', '192', 'AL'],
#  ['Vredenburgh town', '312', 'AL'],
#  ['Wadley town', '751', 'AL'],
#  ['Waldo town', '283', 'AL'],
#  ['Walnut Grove town', '698', 'AL'],
#  ['Warrior city', '3176', 'AL'],
#  ['Waterloo town', '203', 'AL'],
#  ['Waverly town', '145', 'AL'],
#  ['Weaver city', '3038', 'AL'],
#  ['Webb town', '1430', 'AL'],
#  ['Wedowee town', '823', 'AL'],
#  ['Weogufka CDP', '282', 'AL'],
#  ['West Blocton town', '1240', 'AL'],
#  ['West End-Cobb Town CDP', '3465', 'AL'],
#  ['West Jefferson town', '338', 'AL'],
#  ['Westover town', '1275', 'AL'],
#  ['West Point town', '586', 'AL'],
#  ['Wetumpka city', '6528', 'AL'],
#  ['Whatley CDP', '150', 'AL'],
#  ['White Hall town', '858', 'AL'],
#  ['White Plains CDP', '811', 'AL'],
#  ['Whitesboro CDP', '2138', 'AL'],
#  ['Wilsonville town', '1827', 'AL'],
#  ['Wilton town', '687', 'AL'],
#  ['Winfield city', '4717', 'AL'],
#  ['Woodland town', '184', 'AL'],
#  ['Woodstock town', '1428', 'AL'],
#  ['Woodville town', '746', 'AL'],
#  ['Yellow Bluff town', '188', 'AL'],
#  ['York city', '2538', 'AL'],
#  ['Adak city', '326', 'AK'],
#  ['Akhiok city', '71', 'AK'],
#  ['Akiachak CDP', '627', 'AK'],
#  ['Akiak city', '346', 'AK'],
#  ['Akutan city', '1027', 'AK'],
#  ['Alakanuk city', '677', 'AK'],
#  ['Alatna CDP', '37', 'AK'],
#  ['Alcan Border CDP', '33', 'AK'],
#  ['Aleknagik city', '219', 'AK'],
#  ['Aleneva CDP', '37', 'AK'],
#  ['Allakaket city', '105', 'AK'],
#  ['Ambler city', '258', 'AK'],
#  ['Anaktuvuk Pass city', '324', 'AK'],
#  ['Anchorage municipality', '291826', 'AK'],
#  ['Anchor Point CDP', '1930', 'AK'],
#  ['Anderson city', '246', 'AK'],
#  ['Angoon city', '459', 'AK'],
#  ['Aniak city', '501', 'AK'],
#  ['Anvik city', '85', 'AK'],
#  ['Arctic Village CDP', '152', 'AK'],
#  ['Atka city', '61', 'AK'],
#  ['Atmautluak CDP', '277', 'AK'],
#  ['Atqasuk city', '233', 'AK'],
#  ['Attu Station CDP', '21', 'AK'],
#  ['Badger CDP', '19482', 'AK'],
#  ['Barrow city', '4212', 'AK'],
#  ['Bear Creek CDP', '1956', 'AK'],
#  ['Beaver CDP', '84', 'AK'],
#  ['Beluga CDP', '20', 'AK'],
#  ['Bethel city', '6080', 'AK'],
#  ['Bettles city', '12', 'AK'],
#  ['Big Delta CDP', '591', 'AK'],
#  ['Big Lake CDP', '3350', 'AK'],
#  ['Birch Creek CDP', '33', 'AK'],
#  ['Brevig Mission city', '388', 'AK'],
#  ['Buckland city', '416', 'AK'],
#  ['Buffalo Soapstone CDP', '855', 'AK'],
#  ['Butte CDP', '3246', 'AK'],
#  ['Cantwell CDP', '219', 'AK'],
#  ['Central CDP', '96', 'AK'],
#  ['Chalkyitsik CDP', '69', 'AK'],
#  ['Chase CDP', '34', 'AK'],
#  ['Chefornak city', '418', 'AK'],
#  ['Chena Ridge CDP', '5791', 'AK'],
#  ['Chenega CDP', '76', 'AK'],
#  ['Chevak city', '938', 'AK'],
#  ['Chickaloon CDP', '272', 'AK'],
#  ['Chicken CDP', '7', 'AK'],
#  ['Chignik city', '91', 'AK'],
#  ['Chignik Lagoon CDP', '78', 'AK'],
#  ['Chignik Lake CDP', '73', 'AK'],
#  ['Chiniak CDP', '47', 'AK'],
#  ['Chisana CDP', '0', 'AK'],
#  ['Chistochina CDP', '93', 'AK'],
#  ['Chitina CDP', '126', 'AK'],
#  ['Chuathbaluk city', '118', 'AK'],
#  ['Circle CDP', '104', 'AK'],
#  ['Clam Gulch CDP', '176', 'AK'],
#  ["Clark's Point city", '62', 'AK'],
#  ['Coffman Cove city', '176', 'AK'],
#  ['Cohoe CDP', '1364', 'AK'],
#  ['Cold Bay city', '108', 'AK'],
#  ['Coldfoot CDP', '10', 'AK'],
#  ['College CDP', '12964', 'AK'],
#  ['Cooper Landing CDP', '289', 'AK'],
#  ['Copper Center CDP', '328', 'AK'],
#  ['Cordova city', '2239', 'AK'],
#  ['Covenant Life CDP', '86', 'AK'],
#  ['Craig city', '1201', 'AK'],
#  ['Crooked Creek CDP', '105', 'AK'],
#  ['Crown Point CDP', '74', 'AK'],
#  ['Deering city', '122', 'AK'],
#  ['Delta Junction city', '958', 'AK'],
#  ['Deltana CDP', '2251', 'AK'],
#  ['Diamond Ridge CDP', '1156', 'AK'],
#  ['Dillingham city', '2329', 'AK'],
#  ['Diomede city', '115', 'AK'],
#  ['Dot Lake CDP', '13', 'AK'],
#  ['Dot Lake Village CDP', '62', 'AK'],
#  ['Dry Creek CDP', '94', 'AK'],
#  ['Eagle city', '86', 'AK'],
#  ['Eagle Village CDP', '67', 'AK'],
#  ['Edna Bay CDP', '42', 'AK'],
#  ['Eek city', '296', 'AK'],
#  ['Egegik city', '109', 'AK'],
#  ['Eielson AFB CDP', '2647', 'AK'],
#  ['Ekwok city', '115', 'AK'],
#  ['Elfin Cove CDP', '20', 'AK'],
#  ['Elim city', '330', 'AK'],
#  ['Emmonak city', '762', 'AK'],
#  ['Ester CDP', '2422', 'AK'],
#  ['Eureka Roadhouse CDP', '29', 'AK'],
#  ['Evansville CDP', '15', 'AK'],
#  ['Excursion Inlet CDP', '12', 'AK'],
#  ['Fairbanks city', '31535', 'AK'],
#  ['False Pass city', '35', 'AK'],
#  ['Farmers Loop CDP', '4853', 'AK'],
#  ['Farm Loop CDP', '1028', 'AK'],
#  ['Ferry CDP', '33', 'AK'],
#  ['Fishhook CDP', '4679', 'AK'],
#  ['Flat CDP', '0', 'AK'],
#  ['Fort Greely CDP', '539', 'AK'],
#  ['Fort Yukon city', '583', 'AK'],
#  ['Four Mile Road CDP', '43', 'AK'],
#  ['Fox CDP', '417', 'AK'],
#  ['Fox River CDP', '685', 'AK'],
#  ['Fritz Creek CDP', '1932', 'AK'],
#  ['Funny River CDP', '877', 'AK'],
#  ['Gakona CDP', '218', 'AK'],
#  ['Galena city', '470', 'AK'],
#  ['Gambell city', '681', 'AK'],
#  ['Game Creek CDP', '18', 'AK'],
#  ['Gateway CDP', '5552', 'AK'],
#  ['Glacier View CDP', '234', 'AK'],
#  ['Glennallen CDP', '483', 'AK'],
#  ['Goldstream CDP', '3557', 'AK'],
#  ['Golovin city', '156', 'AK'],
#  ['Goodnews Bay city', '243', 'AK'],
#  ['Grayling city', '194', 'AK'],
#  ['Gulkana CDP', '119', 'AK'],
#  ['Gustavus city', '442', 'AK'],
#  ['Haines CDP', '1713', 'AK'],
#  ['Halibut Cove CDP', '76', 'AK'],
#  ['Happy Valley CDP', '593', 'AK'],
#  ['Harding-Birch Lakes CDP', '299', 'AK'],
#  ['Healy CDP', '1021', 'AK'],
#  ['Healy Lake CDP', '13', 'AK'],
#  ['Hobart Bay CDP', '1', 'AK'],
#  ['Hollis CDP', '112', 'AK'],
#  ['Holy Cross city', '178', 'AK'],
#  ['Homer city', '5003', 'AK'],
#  ['Hoonah city', '760', 'AK'],
#  ['Hooper Bay city', '1093', 'AK'],
#  ['Hope CDP', '192', 'AK'],
#  ['Houston city', '1912', 'AK'],
#  ['Hughes city', '77', 'AK'],
#  ['Huslia city', '275', 'AK'],
#  ['Hydaburg city', '376', 'AK'],
#  ['Hyder CDP', '87', 'AK'],
#  ['Igiugig CDP', '50(r38845)', 'AK'],
#  ['Iliamna CDP', '109', 'AK'],
#  ['Ivanof Bay CDP', '7', 'AK'],
#  ['Juneau city and borough', '31275', 'AK'],
#  ['Kachemak city', '472', 'AK'],
#  ['Kake city', '557', 'AK'],
#  ['Kaktovik city', '239', 'AK'],
#  ['Kalifornsky CDP', '7850', 'AK'],
#  ['Kaltag city', '190', 'AK'],
#  ['Karluk CDP', '37', 'AK'],
#  ['Kasaan city', '49', 'AK'],
#  ['Kasigluk CDP', '569', 'AK'],
#  ['Kasilof CDP', '549', 'AK'],
#  ['Kenai city', '7100(r38846)', 'AK'],
#  ['Kenny Lake CDP', '355', 'AK'],
#  ['Ketchikan city', '8050', 'AK'],
#  ['Kiana city', '361', 'AK'],
#  ['King Cove city', '938', 'AK'],
#  ['King Salmon CDP', '374', 'AK'],
#  ['Kipnuk CDP', '639', 'AK'],
#  ['Kivalina city', '374', 'AK'],
#  ['Klawock city', '755', 'AK'],
#  ['Klukwan CDP', '95', 'AK'],
#  ['Knik-Fairview CDP', '14923', 'AK'],
#  ['Knik River CDP', '744', 'AK'],
#  ['Kobuk city', '151', 'AK'],
#  ['Kodiak city', '6130', 'AK'],
#  ['Kodiak Station CDP', '1301', 'AK'],
#  ['Kokhanok CDP', '170', 'AK'],
#  ['Koliganek CDP', '209', 'AK'],
#  ['Kongiganak CDP', '439', 'AK'],
#  ['Kotlik city', '577', 'AK'],
#  ['Kotzebue city', '3201', 'AK'],
#  ['Koyuk city', '332', 'AK'],
#  ['Koyukuk city', '96', 'AK'],
#  ['Kupreanof city', '27', 'AK'],
#  ['Kwethluk city', '721', 'AK'],
#  ['Kwigillingok CDP', '321', 'AK'],
#  ['Lake Louise CDP', '46', 'AK'],
#  ['Lake Minchumina CDP', '13', 'AK'],
#  ['Lakes CDP', '8364', 'AK'],
#  ['Larsen Bay city', '87', 'AK'],
#  ['Lazy Mountain CDP', '1479', 'AK'],
#  ['Levelock CDP', '69', 'AK'],
#  ['Lime Village CDP', '29', 'AK'],
#  ['Livengood CDP', '13', 'AK'],
#  ['Loring CDP', '4', 'AK'],
#  ['Lowell Point CDP', '80', 'AK'],
#  ['Lower Kalskag city', '282', 'AK'],
#  ['Lutak CDP', '49', 'AK'],
#  ['McCarthy CDP', '28', 'AK'],
#  ['McGrath city', '346', 'AK'],
#  ['McKinley Park CDP', '185', 'AK'],
#  ['Manley Hot Springs CDP', '89', 'AK'],
#  ['Manokotak city', '442', 'AK'],
#  ['Marshall city', '414', 'AK'],
#  ['Meadow Lakes CDP', '7570', 'AK'],
#  ['Mekoryuk city', '191', 'AK'],
#  ['Mendeltna CDP', '39', 'AK'],
#  ['Mentasta Lake CDP', '112', 'AK'],
#  ['Mertarvik CDP', '0', 'AK'],
#  ['Metlakatla CDP', '1405', 'AK'],
#  ['Minto CDP', '210', 'AK'],
#  ['Moose Creek CDP', '747', 'AK'],
#  ['Moose Pass CDP', '219', 'AK'],
#  ['Mosquito Lake CDP', '309', 'AK'],
#  ['Mountain Village city', '813', 'AK'],
#  ['Mud Bay CDP', '212', 'AK'],
#  ['Nabesna CDP', '5', 'AK'],
#  ['Naknek CDP', '544', 'AK'],
#  ['Nanwalek CDP', '254', 'AK'],
#  ['Napakiak city', '354', 'AK'],
#  ['Napaskiak city', '405', 'AK'],
#  ['Naukati Bay CDP', '113', 'AK'],
#  ['Nelchina CDP', '59', 'AK'],
#  ['Nelson Lagoon CDP', '52', 'AK'],
#  ['Nenana city', '378', 'AK'],
#  ['New Allakaket CDP', '66', 'AK'],
#  ['Newhalen city', '190', 'AK'],
#  ['New Stuyahok city', '510', 'AK'],
#  ['Newtok CDP', '354', 'AK'],
#  ['Nightmute city', '280', 'AK'],
#  ['Nikiski CDP', '4493', 'AK'],
#  ['Nikolaevsk CDP', '318', 'AK'],
#  ['Nikolai city', '94', 'AK'],
#  ['Nikolski CDP', '18', 'AK'],
#  ['Ninilchik CDP', '883', 'AK'],
#  ['Noatak CDP', '514', 'AK'],
#  ['Nome city', '3598', 'AK'],
#  ['Nondalton city', '164', 'AK'],
#  ['Noorvik city', '668', 'AK'],
#  ['North Pole city', '2117', 'AK'],
#  ['Northway CDP', '71', 'AK'],
#  ['Northway Junction CDP', '54', 'AK'],
#  ['Northway Village CDP', '98', 'AK'],
#  ['Nuiqsut city', '402', 'AK'],
#  ['Nulato city', '264', 'AK'],
#  ['Nunam Iqua city', '187', 'AK'],
#  ['Nunapitchuk city', '496', 'AK'],
#  ['Old Harbor city', '218', 'AK'],
#  ['Oscarville CDP', '70', 'AK'],
#  ['Ouzinkie city', '161', 'AK'],
#  ['Palmer city', '5937', 'AK'],
#  ['Paxson CDP', '40', 'AK'],
#  ['Pedro Bay CDP', '42', 'AK'],
#  ['Pelican city', '88', 'AK'],
#  ['Perryville CDP', '113', 'AK'],
#  ['Petersburg city', '2948', 'AK'],
#  ['Petersville CDP', '4', 'AK'],
#  ['Pilot Point city', '68', 'AK'],
#  ['Pilot Station city', '568', 'AK'],
#  ['Pitkas Point CDP', '109', 'AK'],
#  ['Platinum city', '61', 'AK'],
#  ['Pleasant Valley CDP', '725', 'AK'],
#  ['Point Baker CDP', '15', 'AK'],
#  ['Point Hope city', '674', 'AK'],
#  ['Point Lay CDP', '189', 'AK'],
#  ['Point MacKenzie CDP', '529', 'AK'],
#  ['Point Possession CDP', '3', 'AK'],
#  ['Pope-Vannoy Landing CDP', '6', 'AK'],
#  ['Portage Creek CDP', '2', 'AK'],
#  ['Port Alexander city', '52', 'AK'],
#  ['Port Alsworth CDP', '159', 'AK'],
#  ['Port Clarence CDP', '24', 'AK'],
#  ['Port Graham CDP', '177', 'AK'],
#  ['Port Heiden city', '102', 'AK'],
#  ['Port Lions city', '194', 'AK'],
#  ['Port Protection CDP', '48', 'AK'],
#  ['Primrose CDP', '78', 'AK'],
#  ['Prudhoe Bay CDP', '2174', 'AK'],
#  ['Quinhagak city', '669', 'AK'],
#  ['Rampart CDP', '24', 'AK'],
#  ['Red Devil CDP', '23', 'AK'],
#  ['Red Dog Mine CDP', '309', 'AK'],
#  ['Ridgeway CDP', '2022', 'AK'],
#  ['Ruby city', '166', 'AK'],
#  ['Russian Mission city', '312', 'AK'],
#  ['St. George city', '102', 'AK'],
#  ["St. Mary's city", '507', 'AK'],
#  ['St. Michael city', '401', 'AK'],
#  ['St. Paul city', '479', 'AK'],
#  ['Salamatof CDP', '980', 'AK'],
#  ['Salcha CDP', '1095', 'AK'],
#  ['Sand Point city', '976', 'AK'],
#  ['Savoonga city', '671', 'AK'],
#  ['Saxman city', '411', 'AK'],
#  ['Scammon Bay city', '474', 'AK'],
#  ['Selawik city', '829', 'AK'],
#  ['Seldovia city', '255', 'AK'],
#  ['Seldovia Village CDP', '165', 'AK'],
#  ['Seward city', '2693', 'AK'],
#  ['Shageluk city', '83', 'AK'],
#  ['Shaktoolik city', '251', 'AK'],
#  ['Shishmaref city', '563', 'AK'],
#  ['Shungnak city', '262', 'AK'],
#  ['Silver Springs CDP', '114', 'AK'],
#  ['Sitka city and borough', '8881', 'AK'],
#  ['Skagway CDP', '920', 'AK'],
#  ['Skwentna CDP', '37', 'AK'],
#  ['Slana CDP', '147', 'AK'],
#  ['Sleetmute CDP', '86', 'AK'],
#  ['Soldotna city', '4163', 'AK'],
#  ['South Naknek CDP', '79', 'AK'],
#  ['South Van Horn CDP', '558', 'AK'],
#  ['Stebbins city', '556', 'AK'],
#  ['Steele Creek CDP', '6662', 'AK'],
#  ['Sterling CDP', '5617', 'AK'],
#  ['Stevens Village CDP', '78', 'AK'],
#  ['Stony River CDP', '54', 'AK'],
#  ['Sunrise CDP', '18', 'AK'],
#  ['Susitna CDP', '18', 'AK'],
#  ['Susitna North CDP', '1260', 'AK'],
#  ['Sutton-Alpine CDP', '1447', 'AK'],
#  ['Takotna CDP', '52', 'AK'],
#  ['Talkeetna CDP', '876', 'AK'],
#  ['Tanacross CDP', '136', 'AK'],
#  ['Tanaina CDP', '8197', 'AK'],
#  ['Tanana city', '246', 'AK'],
#  ['Tatitlek CDP', '88', 'AK'],
#  ['Tazlina CDP', '297', 'AK'],
#  ['Teller city', '229', 'AK'],
#  ['Tenakee Springs city', '131', 'AK'],
#  ['Tetlin CDP', '127', 'AK'],
#  ['Thorne Bay city', '471', 'AK'],
#  ['Togiak city', '817', 'AK'],
#  ['Tok CDP', '1258', 'AK'],
#  ['Toksook Bay city', '590', 'AK'],
#  ['Tolsona CDP', '30', 'AK'],
#  ['Tonsina CDP', '78', 'AK'],
#  ['Trapper Creek CDP', '481', 'AK'],
#  ['Tuluksak CDP', '373', 'AK'],
#  ['Tuntutuliak CDP', '408', 'AK'],
#  ['Tununak CDP', '327', 'AK'],
#  ['Twin Hills CDP', '74', 'AK'],
#  ['Two Rivers CDP', '719', 'AK'],
#  ['Tyonek CDP', '171', 'AK'],
#  ['Ugashik CDP', '12', 'AK'],
#  ['Unalakleet city', '688', 'AK'],
#  ['Unalaska city', '4376', 'AK'],
#  ['Upper Kalskag city', '210', 'AK'],
#  ['Valdez city', '3976', 'AK'],
#  ['Venetie CDP', '166', 'AK'],
#  ['Wainwright city', '556', 'AK'],
#  ['Wales city', '145', 'AK'],
#  ['Wasilla city', '7831', 'AK'],
#  ['Whale Pass CDP', '31', 'AK'],
#  ['White Mountain city', '190', 'AK'],
#  ['Whitestone CDP', '97', 'AK'],
#  ['Whitestone Logging Camp CDP', '17', 'AK'],
#  ['Whittier city', '220', 'AK'],
#  ['Willow CDP', '2102', 'AK'],
#  ['Willow Creek CDP', '191', 'AK'],
#  ['Wiseman CDP', '14', 'AK'],
#  ['Womens Bay CDP', '719', 'AK'],
#  ['Wrangell city and borough', '2369', 'AK'],
#  ['Yakutat CDP', '662', 'AK'],
#  ['Aguila CDP', '798', 'AZ'],
#  ['Ajo CDP', '3304', 'AZ'],
#  ['Ak Chin CDP', '30', 'AZ'],
#  ['Ak-Chin Village CDP', '862', 'AZ'],
#  ['Alamo Lake CDP', '25', 'AZ'],
#  ['Ali Chuk CDP', '161', 'AZ'],
#  ['Ali Chukson CDP', '132', 'AZ'],
#  ['Ali Molina CDP', '71', 'AZ'],
#  ['Alpine CDP', '145', 'AZ'],
#  ['Amado CDP', '295', 'AZ'],
#  ['Anegam CDP', '151', 'AZ'],
#  ['Antares CDP', '126', 'AZ'],
#  ['Anthem CDP', '21700', 'AZ'],
#  ['Apache Junction city', '35840', 'AZ'],
#  ['Arivaca CDP', '695', 'AZ'],
#  ['Arivaca Junction CDP', '1090', 'AZ'],
#  ['Arizona City CDP', '10475', 'AZ'],
#  ['Arizona Village CDP', '946', 'AZ'],
#  ['Arlington CDP', '194', 'AZ'],
#  ['Ash Fork CDP', '396', 'AZ'],
#  ['Avenue B and C CDP', '4176', 'AZ'],
#  ['Avondale city', '76238', 'AZ'],
#  ['Avra Valley CDP', '6050', 'AZ'],
#  ['Aztec CDP', '47', 'AZ'],
#  ['Bagdad CDP', '1876', 'AZ'],
#  ['Bear Flat CDP', '18', 'AZ'],
#  ['Beaver Dam CDP', '1962', 'AZ'],
#  ['Beaver Valley CDP', '231', 'AZ'],
#  ['Benson city', '5105', 'AZ'],
#  ['Beyerville CDP', '177', 'AZ'],
#  ['Bisbee city', '5575', 'AZ'],
#  ['Bitter Springs CDP', '452', 'AZ'],
#  ['Black Canyon City CDP', '2837', 'AZ'],
#  ['Blackwater CDP', '1062', 'AZ'],
#  ['Bluewater CDP', '725', 'AZ'],
#  ['Bouse CDP', '996', 'AZ'],
#  ['Bowie CDP', '449', 'AZ'],
#  ['Brenda CDP', '676', 'AZ'],
#  ['Bryce CDP', '175', 'AZ'],
#  ['Buckeye town', '50876', 'AZ'],
#  ['Buckshot CDP', '153', 'AZ'],
#  ['Bullhead City city', '39540', 'AZ'],
#  ['Burnside CDP', '537', 'AZ'],
#  ['Bylas CDP', '1962', 'AZ'],
#  ['Cactus Flats CDP', '1518', 'AZ'],
#  ['Cactus Forest CDP', '594', 'AZ'],
#  ['Cameron CDP', '885', 'AZ'],
#  ['Campo Bonito CDP', '74', 'AZ'],
#  ['Camp Verde town', '10873', 'AZ'],
#  ['Cane Beds CDP', '448', 'AZ'],
#  ['Canyon Day CDP', '1209', 'AZ'],
#  ['Carefree town', '3363', 'AZ'],
#  ['Carrizo CDP', '127', 'AZ'],
#  ['Casa Blanca CDP', '1388', 'AZ'],
#  ['Casa Grande city', '48571', 'AZ'],
#  ['Casas Adobes CDP', '66795', 'AZ'],
#  ['Catalina CDP', '7569', 'AZ'],
#  ['Catalina Foothills CDP', '50796', 'AZ'],
#  ['Cave Creek town', '5015', 'AZ'],
#  ['Cedar Creek CDP', '318', 'AZ'],
#  ['Centennial Park CDP', '1264', 'AZ'],
#  ['Central CDP', '645', 'AZ'],
#  ['Central Heights-Midland City CDP', '2534', 'AZ'],
#  ['Chandler city', '236123(r39187)', 'AZ'],
#  ['Charco CDP', '52', 'AZ'],
#  ['Chiawuli Tak CDP', '78', 'AZ'],
#  ['Chilchinbito CDP', '506', 'AZ'],
#  ...]

# %%
'Adding Income'
comp_1_i = pd.read_csv('MedianHouseholdIncome2015.csv', encoding = "ISO-8859-1")

comp_1_i['Median Income'] = comp_1_i['Median Income'].str.replace(r'\(.*\)', '0')#removes anything that has a () in it, done to try to clean up data
comp_1_i['Median Income'] = comp_1_i['Median Income'].str.replace(r'.*\-.*', '0')
comp_1_i['Median Income'] = comp_1_i['Median Income'].str.replace(r'\+', '')
comp_1_i['Median Income'] = comp_1_i['Median Income'].str.replace(r'\,', '')
comp_1_i['City'] = comp_1_i['City'].str.replace(r'\-.*', '')#removes everything after -, used to add more per capita counts 
comp_1_i['City'] = comp_1_i['City'].str.replace(r'\/.*', '')#removes everything after /, used to add more per capita counts 
comp_1_i['City'] = comp_1_i['City'].str.replace(r" (balance)", '')#removes everything in a cell if it has (balance) in it,prevents double counting 
comp_1_i['City'] = comp_1_i['City'].str.replace(r'\(.*\)', '')#removes anything that has a parenthesis in it, done to try to clean up data
comp_1_i['City'] = comp_1_i['City'].str.replace(r' CDP', '')#removes anything that has a 'CDP' in it, done to try to clean up data
comp_1_i['City'] = comp_1_i['City'].str.replace(r' city', '')#removes anything that has a lowercase spelling of 'city' in it, done to try to clean up data
comp_1_i['City'] = comp_1_i['City'].str.replace(r' village', '')#removes lowercase villages
comp_1_i['City'] = comp_1_i['City'].str.replace(r' municipality', '')#removes municipality, mainly to deal with Anchorage
comp_1_i['City'] = comp_1_i['City'].str.replace(r' town', '')#removes lowercase town
comp_1_i['City'] = comp_1_i['City'].str.replace(r'Urban ', '')#Removes Urban , for Honolulu


type_dict = {'Geographic Area': 'str', 'City': 'str', 'Median Income': 'int64'}#done to change population values into an integer
comp_1_i = comp_1_i.astype(type_dict)#done to change population values into an integer

# %%
'making data useable'
comp_1_i_lst=[]
for i in range(len(comp_1_i)):
    comp_1_i_lst.append([comp_1_i['City'][i],comp_1_i['Median Income'][i],comp_1_i['Geographic Area'][i]])

# %%
'Adding Poverty Rate'
comp_2 = pd.read_csv('PercentagePeopleBelowPovertyLevel.csv', encoding = "ISO-8859-1")

comp_2['poverty_rate'] = comp_2['poverty_rate'].str.replace(r'\(.*\)', '0')#removes anything that has a () in it, done to try to clean up data
comp_2['poverty_rate'] = comp_2['poverty_rate'].str.replace(r'.*\-.*', '0')
comp_2['poverty_rate'] = comp_2['poverty_rate'].str.replace(r'\+', '')
comp_2['poverty_rate'] = comp_2['poverty_rate'].str.replace(r'\,', '')
comp_2['City'] = comp_2['City'].str.replace(r'\-.*', '')#removes everything after -, used to add more per capita counts 
comp_2['City'] = comp_2['City'].str.replace(r'\/.*', '')#removes everything after /, used to add more per capita counts 
comp_2['City'] = comp_2['City'].str.replace(r" (balance)", '')#removes everything in a cell if it has (balance) in it,prevents double counting 
comp_2['City'] = comp_2['City'].str.replace(r'\(.*\)', '')#removes anything that has a parenthesis in it, done to try to clean up data
comp_2['City'] = comp_2['City'].str.replace(r' CDP', '')#removes anything that has a 'CDP' in it, done to try to clean up data
comp_2['City'] = comp_2['City'].str.replace(r' city', '')#removes anything that has a lowercase spelling of 'city' in it, done to try to clean up data
comp_2['City'] = comp_2['City'].str.replace(r' village', '')#removes lowercase villages
comp_2['City'] = comp_2['City'].str.replace(r' municipality', '')#removes municipality, mainly to deal with Anchorage
comp_2['City'] = comp_2['City'].str.replace(r' town', '')#removes lowercase town
comp_2['City'] = comp_2['City'].str.replace(r'Urban ', '')#Removes Urban , for Honolulu


type_dict = {'Geographic Area': 'str', 'City': 'str', 'poverty_rate': 'float64'}#done to change population values into an integer
comp_2 = comp_2.astype(type_dict)#done to change population values into an integer

# %%
'making data useable'
comp_2_lst=[]
for i in range(len(comp_2)):
    comp_2_lst.append([comp_2['City'][i],comp_2['poverty_rate'][i],comp_2['Geographic Area'][i]])

# %%
'Adding Education'
comp_3 = pd.read_csv('PercentOver25CompletedHighSchool.csv', encoding = "ISO-8859-1")

comp_3['percent_completed_hs'] = comp_3['percent_completed_hs'].str.replace(r'\(.*\)', '0')#removes anything that has a () in it, done to try to clean up data
comp_3['percent_completed_hs'] = comp_3['percent_completed_hs'].str.replace(r'.*\-.*', '0')
comp_3['percent_completed_hs'] = comp_3['percent_completed_hs'].str.replace(r'\+', '')
comp_3['percent_completed_hs'] = comp_3['percent_completed_hs'].str.replace(r'\,', '')
comp_3['City'] = comp_3['City'].str.replace(r'\-.*', '')#removes everything after -, used to add more per capita counts 
comp_3['City'] = comp_3['City'].str.replace(r'\/.*', '')#removes everything after /, used to add more per capita counts 
comp_3['City'] = comp_3['City'].str.replace(r" (balance)", '')#removes everything in a cell if it has (balance) in it,prevents double counting 
comp_3['City'] = comp_3['City'].str.replace(r'\(.*\)', '')#removes anything that has a parenthesis in it, done to try to clean up data
comp_3['City'] = comp_3['City'].str.replace(r' CDP', '')#removes anything that has a 'CDP' in it, done to try to clean up data
comp_3['City'] = comp_3['City'].str.replace(r' city', '')#removes anything that has a lowercase spelling of 'city' in it, done to try to clean up data
comp_3['City'] = comp_3['City'].str.replace(r' village', '')#removes lowercase villages
comp_3['City'] = comp_3['City'].str.replace(r' municipality', '')#removes municipality, mainly to deal with Anchorage
comp_3['City'] = comp_3['City'].str.replace(r' town', '')#removes lowercase town
comp_3['City'] = comp_3['City'].str.replace(r'Urban ', '')#Removes Urban , for Honolulu


type_dict = {'Geographic Area': 'str', 'City': 'str', 'percent_completed_hs': 'float64'}#done to change population values into an integer
comp_3 = comp_3.astype(type_dict)#done to change population values into an integer

# %%
'making data useable'
comp_3_lst=[]
for i in range(len(comp_3)):
    comp_3_lst.append([comp_3['City'][i],comp_3['percent_completed_hs'][i],comp_3['Geographic Area'][i]])

# %%
'Adding Race'
comp_4 = pd.read_csv('ShareRaceByCity.csv', encoding = "ISO-8859-1")
print(len(comp_4))

print(comp_4.dtypes) #shows the type of data contained in cells

print(len(comp_4))

comp_4['share_white'] = comp_4['share_white'].str.replace(r'\(.*\)', '0')#removes anything that has a () in it, done to try to clean up data
comp_4['share_white'] = comp_4['share_white'].str.replace(r'.*\-.*', '0')
comp_4['share_white'] = comp_4['share_white'].str.replace(r'\+', '')
comp_4['share_white'] = comp_4['share_white'].str.replace(r'\,', '')

comp_4['share_black'] = comp_4['share_black'].str.replace(r'\(.*\)', '0')#removes anything that has a () in it, done to try to clean up data
comp_4['share_black'] = comp_4['share_black'].str.replace(r'.*\-.*', '0')
comp_4['share_black'] = comp_4['share_black'].str.replace(r'\+', '')
comp_4['share_black'] = comp_4['share_black'].str.replace(r'\,', '')

comp_4['share_native_american'] = comp_4['share_native_american'].str.replace(r'\(.*\)', '0')#removes anything that has a () in it, done to try to clean up data
comp_4['share_native_american'] = comp_4['share_native_american'].str.replace(r'.*\-.*', '0')
comp_4['share_native_american'] = comp_4['share_native_american'].str.replace(r'\+', '')
comp_4['share_native_american'] = comp_4['share_native_american'].str.replace(r'\,', '')

comp_4['share_asian'] = comp_4['share_asian'].str.replace(r'\(.*\)', '0')#removes anything that has a () in it, done to try to clean up data
comp_4['share_asian'] = comp_4['share_asian'].str.replace(r'.*\-.*', '0')
comp_4['share_asian'] = comp_4['share_asian'].str.replace(r'\+', '')
comp_4['share_asian'] = comp_4['share_asian'].str.replace(r'\,', '')

comp_4['share_hispanic'] = comp_4['share_hispanic'].str.replace(r'\(.*\)', '0')#removes anything that has a () in it, done to try to clean up data
comp_4['share_hispanic'] = comp_4['share_hispanic'].str.replace(r'.*\-.*', '0')
comp_4['share_hispanic'] = comp_4['share_hispanic'].str.replace(r'\+', '')
comp_4['share_hispanic'] = comp_4['share_hispanic'].str.replace(r'\,', '')

comp_4['City'] = comp_4['City'].str.replace(r'\-.*', '')#removes everything after -, used to add more per capita counts 
comp_4['City'] = comp_4['City'].str.replace(r'\/.*', '')#removes everything after /, used to add more per capita counts 
comp_4['City'] = comp_4['City'].str.replace(r" (balance)", '')#removes everything in a cell if it has (balance) in it,prevents double counting 
comp_4['City'] = comp_4['City'].str.replace(r'\(.*\)', '')#removes anything that has a parenthesis in it, done to try to clean up data
comp_4['City'] = comp_4['City'].str.replace(r' CDP', '')#removes anything that has a 'CDP' in it, done to try to clean up data
comp_4['City'] = comp_4['City'].str.replace(r' city', '')#removes anything that has a lowercase spelling of 'city' in it, done to try to clean up data
comp_4['City'] = comp_4['City'].str.replace(r' village', '')#removes lowercase villages
comp_4['City'] = comp_4['City'].str.replace(r' municipality', '')#removes municipality, mainly to deal with Anchorage
comp_4['City'] = comp_4['City'].str.replace(r' town', '')#removes lowercase town
comp_4['City'] = comp_4['City'].str.replace(r'Urban ', '')#Removes Urban , for Honolulu


type_dict_4 = {'Geographic Area': 'str', 'City': 'str', 'share_white': 'float64', 'share_black': 'float64', 'share_native_american': 'float64', 'share_asian': 'float64', 'share_hispanic': 'float64'}#done to change population values into an integer

comp_4 = comp_4.astype(type_dict_4)#done to change population values into an integer


print(len(comp_4))


len(comp_4)
# Out:
# 29263
# Geographic Area          object
# City                     object
# share_white              object
# share_black              object
# share_native_american    object
# share_asian              object
# share_hispanic           object
# dtype: object
# 29263
# 29263
# 29263

# %%
'making data useable'
comp_4_lst=[]
for i in range(len(comp_4)):
    comp_4_lst.append([comp_4['City'][i],[float(comp_4['share_white'][i]),float(comp_4['share_black'][i]),float(comp_4['share_native_american'][i]),float(comp_4['share_asian'][i]),float(comp_4['share_hispanic'][i])],comp_4['Geographic Area'][i]])

# %%
'making a few functions to help later'
def find_city(city_name,lst):
    for i in range(len(lst)):
        if city_name in lst[i][0]:
            print(lst[i])
            print(i)
def find_repeats(lst):
    for i in range(len(lst)):
        if len(lst[i])>4:
            print(lst[i])
def find_emptys(lst):
    for i in range(len(lst)):
        if len(lst[i])==3:
            print(lst[i])

# %%
"making the function that makes list of kills per capita"
def per_capita(city_kill_state,city_pop_lst):
    for i in range(len(city_kill_state)):
        for x in range(len(city_pop_lst)):
            if city_kill_state[i][0] == city_pop_lst[x][0]:
                if city_kill_state[i][2] == city_pop_lst[x][2]:
                    per_capita =100000 * float(city_kill_state[i][1])/float(city_pop_lst[x][1])
                    city_kill_state[i].extend([float(city_pop_lst[x][1]),per_capita])
    print(len(city_kill_state))
    return city_kill_state

# %%
'adding data'
def add_info(thing_youre_adding_to,raw_list):
    for i in range(len(thing_youre_adding_to)):
        for x in range(len(raw_list)):
            if thing_youre_adding_to[i][0] == raw_list[x][0]:
                if thing_youre_adding_to[i][2] == raw_list[x][2]:
                    thing_youre_adding_to[i].append(raw_list[x][1])
    print(len(thing_youre_adding_to))
    return thing_youre_adding_to

# %%
'checking for empties'
def empty_13(fatal_police_shootings_per_capita):
    print(len(fatal_police_shootings_per_capita))
    sfdgdfsg=[]
    for i in range(len(fatal_police_shootings_per_capita)):
        if len(fatal_police_shootings_per_capita[i])<13:
            sfdgdfsg.append(fatal_police_shootings_per_capita[i])
            print(fatal_police_shootings_per_capita[i])
    print(len(sfdgdfsg))
    sfdgdfsg=[]

# %%
'''Adding Cañon City
find_city('Cañon City',fatal_police_shootings_per_capita_w)
[float(41892),20.6,91.1,96.0,1.2,0.6,0.2,10.5]
fatal_police_shootings_per_capita_w[189].extend([float(41892),20.6,91.1,96.0,1.2,0.6,0.2,10.5])
empty(fatal_police_shootings_per_capita_w)'''
# Out:
# "Adding Cañon City\nfind_city('Cañon City',fatal_police_shootings_per_capita_w)\n[float(41892),20.6,91.1,96.0,1.2,0.6,0.2,10.5]\nfatal_police_shootings_per_capita_w[189].extend([float(41892),20.6,91.1,96.0,1.2,0.6,0.2,10.5])\nempty(fatal_police_shootings_per_capita_w)"

# %%
police
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4687  5147                 Michael Pinkerman  2019-10-30              shot
# 4688  5149                             TK TK  2019-10-30              shot
# 4689  5162            Billy Kongphouthakhoun  2019-10-30              shot
# 4690  5163                             TK TK  2019-10-30              shot
# 4691  5160                  Danny James Hall  2019-10-31              shot
# 4692  5161                             TK TK  2019-10-31              shot
# 4693  5150                     Benjamin Diaz  2019-11-01              shot
# 4694  5158                             TK TK  2019-11-01              shot
# 4695  5159              Luis Morales-Camacho  2019-11-01              shot
# 4696  5173              Luis Fino Nabarrette  2019-11-01              shot
# 4697  5155                     Michael Kifer  2019-11-02  shot and Tasered
# 4698  5157                         John Hale  2019-11-02              shot
# 4699  5153                             TK TK  2019-11-03              shot
# 4700  5154                    Michael Austin  2019-11-03              shot
# 4701  5151                             TK TK  2019-11-04              shot
# 4702  5172                 Matthew Rasmussen  2019-11-04              shot
# 4703  5174                   Daniel M. Munoz  2019-11-04              shot
# 4704  5175                             TK TK  2019-11-04              shot
# 4705  5167                     Maurice Brown  2019-11-05              shot
# 4706  5168                     Jay P. Messer  2019-11-05              shot
# 4707  5169                             TK TK  2019-11-05              shot
# 4708  5171              Christopher Alan Noe  2019-11-05  shot and Tasered
# 4709  5164                 Eddie Ray Maxwell  2019-11-06              shot
# 4710  5165               Corben Hunter Jones  2019-11-06              shot
# 4711  5166                             TK TK  2019-11-06              shot
# 4712  5170                  Treva Smutherman  2019-11-06              shot
# 4713  5176                Guy Thomas Barnard  2019-11-07              shot
# 4714  5177                             TK TK  2019-11-07              shot
# 4715  5178               Gerald Newton Allen  2019-11-07              shot
# 4716  5179                 Christopher Mills  2019-11-07              shot
#
#              armed   age gender race                city state  \
# 0              gun  53.0      M    A             Shelton    WA
# 1              gun  47.0      M    W               Aloha    OR
# 2          unarmed  23.0      M    H             Wichita    KS
# 3       toy weapon  32.0      M    W       San Francisco    CA
# 4         nail gun  39.0      M    H               Evans    CO
# 5              gun  18.0      M    W             Guthrie    OK
# 6              gun  22.0      M    H            Chandler    AZ
# 7              gun  35.0      M    W             Assaria    KS
# 8          unarmed  34.0      F    W          Burlington    IA
# 9       toy weapon  47.0      M    B           Knoxville    PA
# 10           knife  25.0      M    W            Stockton    CA
# 11             gun  31.0      M    B            Freeport    TX
# 12           knife  41.0      M    B            Columbus    OH
# 13             gun  30.0      M    W          Des Moines    IA
# 14             gun  37.0      M    B         New Orleans    LA
# 15             NaN  28.0      M    W             Huntley    MT
# 16          shovel  42.0      M    W      Salt Lake City    UT
# 17         unarmed  36.0      M    B              Strong    AR
# 18             gun  49.0      M    W            Syracuse    UT
# 19             gun  71.0      M    W             England    AR
# 20             gun  33.0      M    H             El Paso    TX
# 21             gun  39.0      M    W              Arcola    IL
# 22             gun  23.0      M    H          South Gate    CA
# 23             gun  29.0      M    H     North Las Vegas    NV
# 24             gun  34.0      M    W         Albuquerque    NM
# 25           knife  43.0      M    W          Jourdanton    TX
# 26             NaN  24.0      M    B            St. Paul    MN
# 27             NaN  29.0      M    W     Franklin County    MO
# 28             gun  34.0      M    B          Chesapeake    VA
# 29           knife  75.0      M    W          Old Bridge    NJ
# ...            ...   ...    ...  ...                 ...   ...
# 4687           gun   NaN      M    W                 Ona    WV
# 4688         knife   NaN      M  NaN            San Jose    CA
# 4689           gun   NaN      M    A              Fresno    CA
# 4690            ax   NaN      M  NaN           Lancaster    CA
# 4691           gun  34.0      M    W              Bascom    FL
# 4692    toy weapon   NaN      M  NaN            San Jose    CA
# 4693  sharp object  22.0      M    H          Alamogordo    NM
# 4694  undetermined   NaN      M  NaN        Adams County    CO
# 4695  undetermined  41.0      M    H             Orlando    FL
# 4696           gun  38.0      M    H              Odessa    TX
# 4697         sword  29.0      M    W          Vero Beach    FL
# 4698  undetermined  42.0      M    W              Dexter    KY
# 4699         knife  56.0      M  NaN            Parkland    WA
# 4700           gun  32.0      M    B             Phoenix    AZ
# 4701           gun   NaN      M  NaN        Sunland Park    NM
# 4702  sharp object  31.0      M    W            Glendale    AZ
# 4703           gun  21.0      M    H          Las Cruces    NM
# 4704           gun   NaN      M  NaN          Two Rivers    WI
# 4705           gun  48.0      M    B      East Cleveland    OH
# 4706           gun  58.0      M  NaN       Pettis County    MO
# 4707           gun   NaN      M  NaN                Leon    WI
# 4708         knife  45.0      M  NaN              Willis    TX
# 4709           gun  37.0      M    B           Tahlequah    OK
# 4710  undetermined  20.0      M    W           Henryetta    OK
# 4711           gun   NaN      M  NaN         San Antonio    TX
# 4712           gun  31.0      M    B        Fayetteville    NC
# 4713        BB gun  26.0      M  NaN           Wadsworth    OH
# 4714           gun   NaN      M  NaN          Louisville    KY
# 4715           gun  66.0      M  NaN             Conyers    GA
# 4716           gun  37.0      M  NaN  Ashtabula Township    OH
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# 5                       False        attack  Not fleeing        False
# 6                       False        attack          Car        False
# 7                       False        attack  Not fleeing        False
# 8                       False         other  Not fleeing         True
# 9                       False        attack  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 11                      False        attack  Not fleeing        False
# 12                       True         other  Not fleeing        False
# 13                      False        attack          Car        False
# 14                      False        attack         Foot         True
# 15                      False  undetermined  Not fleeing        False
# 16                      False        attack  Not fleeing         True
# 17                      False        attack  Not fleeing        False
# 18                      False        attack  Not fleeing         True
# 19                      False        attack  Not fleeing        False
# 20                      False        attack  Not fleeing        False
# 21                       True        attack  Not fleeing        False
# 22                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 24                      False        attack         Foot         True
# 25                       True         other  Not fleeing        False
# 26                      False        attack  Not fleeing        False
# 27                      False        attack  Not fleeing        False
# 28                       True        attack  Not fleeing        False
# 29                      False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 4687                    False        attack  Not fleeing        False
# 4688                    False         other  Not fleeing        False
# 4689                    False         other  Not fleeing        False
# 4690                    False         other  Not fleeing        False
# 4691                    False        attack          Car        False
# 4692                    False        attack  Not fleeing        False
# 4693                    False        attack          Car        False
# 4694                    False  undetermined          NaN        False
# 4695                    False        attack  Not fleeing        False
# 4696                    False        attack          Car        False
# 4697                    False        attack  Not fleeing        False
# 4698                    False        attack          NaN        False
# 4699                    False         other  Not fleeing        False
# 4700                    False        attack  Not fleeing        False
# 4701                    False        attack         Foot        False
# 4702                     True        attack  Not fleeing        False
# 4703                    False        attack          NaN        False
# 4704                    False         other  Not fleeing        False
# 4705                    False        attack  Not fleeing         True
# 4706                    False        attack  Not fleeing        False
# 4707                    False         other  Not fleeing        False
# 4708                    False         other          Car        False
# 4709                    False        attack  Not fleeing        False
# 4710                    False  undetermined          NaN        False
# 4711                    False         other          NaN        False
# 4712                    False        attack  Not fleeing        False
# 4713                    False        attack          NaN        False
# 4714                    False        attack          NaN        False
# 4715                    False        attack  Not fleeing        False
# 4716                    False         other  Not fleeing        False
#
# [4717 rows x 14 columns]

# %%
police.columns = ['id','Name','Date','Manner of Death','Armed?','Age','Gender','Race','City','State','Signs of Mental Illness','Threat Level','Fleeing?','Body Camera?']
police
# Out:
#         id                              Name        Date   Manner of Death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4687  5147                 Michael Pinkerman  2019-10-30              shot
# 4688  5149                             TK TK  2019-10-30              shot
# 4689  5162            Billy Kongphouthakhoun  2019-10-30              shot
# 4690  5163                             TK TK  2019-10-30              shot
# 4691  5160                  Danny James Hall  2019-10-31              shot
# 4692  5161                             TK TK  2019-10-31              shot
# 4693  5150                     Benjamin Diaz  2019-11-01              shot
# 4694  5158                             TK TK  2019-11-01              shot
# 4695  5159              Luis Morales-Camacho  2019-11-01              shot
# 4696  5173              Luis Fino Nabarrette  2019-11-01              shot
# 4697  5155                     Michael Kifer  2019-11-02  shot and Tasered
# 4698  5157                         John Hale  2019-11-02              shot
# 4699  5153                             TK TK  2019-11-03              shot
# 4700  5154                    Michael Austin  2019-11-03              shot
# 4701  5151                             TK TK  2019-11-04              shot
# 4702  5172                 Matthew Rasmussen  2019-11-04              shot
# 4703  5174                   Daniel M. Munoz  2019-11-04              shot
# 4704  5175                             TK TK  2019-11-04              shot
# 4705  5167                     Maurice Brown  2019-11-05              shot
# 4706  5168                     Jay P. Messer  2019-11-05              shot
# 4707  5169                             TK TK  2019-11-05              shot
# 4708  5171              Christopher Alan Noe  2019-11-05  shot and Tasered
# 4709  5164                 Eddie Ray Maxwell  2019-11-06              shot
# 4710  5165               Corben Hunter Jones  2019-11-06              shot
# 4711  5166                             TK TK  2019-11-06              shot
# 4712  5170                  Treva Smutherman  2019-11-06              shot
# 4713  5176                Guy Thomas Barnard  2019-11-07              shot
# 4714  5177                             TK TK  2019-11-07              shot
# 4715  5178               Gerald Newton Allen  2019-11-07              shot
# 4716  5179                 Christopher Mills  2019-11-07              shot
#
#             Armed?   Age Gender Race                City State  \
# 0              gun  53.0      M    A             Shelton    WA
# 1              gun  47.0      M    W               Aloha    OR
# 2          unarmed  23.0      M    H             Wichita    KS
# 3       toy weapon  32.0      M    W       San Francisco    CA
# 4         nail gun  39.0      M    H               Evans    CO
# 5              gun  18.0      M    W             Guthrie    OK
# 6              gun  22.0      M    H            Chandler    AZ
# 7              gun  35.0      M    W             Assaria    KS
# 8          unarmed  34.0      F    W          Burlington    IA
# 9       toy weapon  47.0      M    B           Knoxville    PA
# 10           knife  25.0      M    W            Stockton    CA
# 11             gun  31.0      M    B            Freeport    TX
# 12           knife  41.0      M    B            Columbus    OH
# 13             gun  30.0      M    W          Des Moines    IA
# 14             gun  37.0      M    B         New Orleans    LA
# 15             NaN  28.0      M    W             Huntley    MT
# 16          shovel  42.0      M    W      Salt Lake City    UT
# 17         unarmed  36.0      M    B              Strong    AR
# 18             gun  49.0      M    W            Syracuse    UT
# 19             gun  71.0      M    W             England    AR
# 20             gun  33.0      M    H             El Paso    TX
# 21             gun  39.0      M    W              Arcola    IL
# 22             gun  23.0      M    H          South Gate    CA
# 23             gun  29.0      M    H     North Las Vegas    NV
# 24             gun  34.0      M    W         Albuquerque    NM
# 25           knife  43.0      M    W          Jourdanton    TX
# 26             NaN  24.0      M    B            St. Paul    MN
# 27             NaN  29.0      M    W     Franklin County    MO
# 28             gun  34.0      M    B          Chesapeake    VA
# 29           knife  75.0      M    W          Old Bridge    NJ
# ...            ...   ...    ...  ...                 ...   ...
# 4687           gun   NaN      M    W                 Ona    WV
# 4688         knife   NaN      M  NaN            San Jose    CA
# 4689           gun   NaN      M    A              Fresno    CA
# 4690            ax   NaN      M  NaN           Lancaster    CA
# 4691           gun  34.0      M    W              Bascom    FL
# 4692    toy weapon   NaN      M  NaN            San Jose    CA
# 4693  sharp object  22.0      M    H          Alamogordo    NM
# 4694  undetermined   NaN      M  NaN        Adams County    CO
# 4695  undetermined  41.0      M    H             Orlando    FL
# 4696           gun  38.0      M    H              Odessa    TX
# 4697         sword  29.0      M    W          Vero Beach    FL
# 4698  undetermined  42.0      M    W              Dexter    KY
# 4699         knife  56.0      M  NaN            Parkland    WA
# 4700           gun  32.0      M    B             Phoenix    AZ
# 4701           gun   NaN      M  NaN        Sunland Park    NM
# 4702  sharp object  31.0      M    W            Glendale    AZ
# 4703           gun  21.0      M    H          Las Cruces    NM
# 4704           gun   NaN      M  NaN          Two Rivers    WI
# 4705           gun  48.0      M    B      East Cleveland    OH
# 4706           gun  58.0      M  NaN       Pettis County    MO
# 4707           gun   NaN      M  NaN                Leon    WI
# 4708         knife  45.0      M  NaN              Willis    TX
# 4709           gun  37.0      M    B           Tahlequah    OK
# 4710  undetermined  20.0      M    W           Henryetta    OK
# 4711           gun   NaN      M  NaN         San Antonio    TX
# 4712           gun  31.0      M    B        Fayetteville    NC
# 4713        BB gun  26.0      M  NaN           Wadsworth    OH
# 4714           gun   NaN      M  NaN          Louisville    KY
# 4715           gun  66.0      M  NaN             Conyers    GA
# 4716           gun  37.0      M  NaN  Ashtabula Township    OH
#
#       Signs of Mental Illness  Threat Level     Fleeing?  Body Camera?
# 0                        True        attack  Not fleeing         False
# 1                       False        attack  Not fleeing         False
# 2                       False         other  Not fleeing         False
# 3                        True        attack  Not fleeing         False
# 4                       False        attack  Not fleeing         False
# 5                       False        attack  Not fleeing         False
# 6                       False        attack          Car         False
# 7                       False        attack  Not fleeing         False
# 8                       False         other  Not fleeing          True
# 9                       False        attack  Not fleeing         False
# 10                      False        attack  Not fleeing         False
# 11                      False        attack  Not fleeing         False
# 12                       True         other  Not fleeing         False
# 13                      False        attack          Car         False
# 14                      False        attack         Foot          True
# 15                      False  undetermined  Not fleeing         False
# 16                      False        attack  Not fleeing          True
# 17                      False        attack  Not fleeing         False
# 18                      False        attack  Not fleeing          True
# 19                      False        attack  Not fleeing         False
# 20                      False        attack  Not fleeing         False
# 21                       True        attack  Not fleeing         False
# 22                      False        attack  Not fleeing         False
# 23                      False        attack         Foot         False
# 24                      False        attack         Foot          True
# 25                       True         other  Not fleeing         False
# 26                      False        attack  Not fleeing         False
# 27                      False        attack  Not fleeing         False
# 28                       True        attack  Not fleeing         False
# 29                      False        attack  Not fleeing         False
# ...                       ...           ...          ...           ...
# 4687                    False        attack  Not fleeing         False
# 4688                    False         other  Not fleeing         False
# 4689                    False         other  Not fleeing         False
# 4690                    False         other  Not fleeing         False
# 4691                    False        attack          Car         False
# 4692                    False        attack  Not fleeing         False
# 4693                    False        attack          Car         False
# 4694                    False  undetermined          NaN         False
# 4695                    False        attack  Not fleeing         False
# 4696                    False        attack          Car         False
# 4697                    False        attack  Not fleeing         False
# 4698                    False        attack          NaN         False
# 4699                    False         other  Not fleeing         False
# 4700                    False        attack  Not fleeing         False
# 4701                    False        attack         Foot         False
# 4702                     True        attack  Not fleeing         False
# 4703                    False        attack          NaN         False
# 4704                    False         other  Not fleeing         False
# 4705                    False        attack  Not fleeing          True
# 4706                    False        attack  Not fleeing         False
# 4707                    False         other  Not fleeing         False
# 4708                    False         other          Car         False
# 4709                    False        attack  Not fleeing         False
# 4710                    False  undetermined          NaN         False
# 4711                    False         other          NaN         False
# 4712                    False        attack  Not fleeing         False
# 4713                    False        attack          NaN         False
# 4714                    False        attack          NaN         False
# 4715                    False        attack  Not fleeing         False
# 4716                    False         other  Not fleeing         False
#
# [4717 rows x 14 columns]

# %%
print(police['Race'].value_counts())
o = police.copy()
not_o = o[o['Race'] == 'O' ].index
o.drop(not_o, inplace=True)
print(len(o))
o
# Out:
# W    2106
# B    1102
# H     802
# A      79
# N      72
# O      40
# Name: Race, dtype: int64
# 4677
#         id                              Name        Date   Manner of Death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4687  5147                 Michael Pinkerman  2019-10-30              shot
# 4688  5149                             TK TK  2019-10-30              shot
# 4689  5162            Billy Kongphouthakhoun  2019-10-30              shot
# 4690  5163                             TK TK  2019-10-30              shot
# 4691  5160                  Danny James Hall  2019-10-31              shot
# 4692  5161                             TK TK  2019-10-31              shot
# 4693  5150                     Benjamin Diaz  2019-11-01              shot
# 4694  5158                             TK TK  2019-11-01              shot
# 4695  5159              Luis Morales-Camacho  2019-11-01              shot
# 4696  5173              Luis Fino Nabarrette  2019-11-01              shot
# 4697  5155                     Michael Kifer  2019-11-02  shot and Tasered
# 4698  5157                         John Hale  2019-11-02              shot
# 4699  5153                             TK TK  2019-11-03              shot
# 4700  5154                    Michael Austin  2019-11-03              shot
# 4701  5151                             TK TK  2019-11-04              shot
# 4702  5172                 Matthew Rasmussen  2019-11-04              shot
# 4703  5174                   Daniel M. Munoz  2019-11-04              shot
# 4704  5175                             TK TK  2019-11-04              shot
# 4705  5167                     Maurice Brown  2019-11-05              shot
# 4706  5168                     Jay P. Messer  2019-11-05              shot
# 4707  5169                             TK TK  2019-11-05              shot
# 4708  5171              Christopher Alan Noe  2019-11-05  shot and Tasered
# 4709  5164                 Eddie Ray Maxwell  2019-11-06              shot
# 4710  5165               Corben Hunter Jones  2019-11-06              shot
# 4711  5166                             TK TK  2019-11-06              shot
# 4712  5170                  Treva Smutherman  2019-11-06              shot
# 4713  5176                Guy Thomas Barnard  2019-11-07              shot
# 4714  5177                             TK TK  2019-11-07              shot
# 4715  5178               Gerald Newton Allen  2019-11-07              shot
# 4716  5179                 Christopher Mills  2019-11-07              shot
#
#             Armed?   Age Gender Race                City State  \
# 0              gun  53.0      M    A             Shelton    WA
# 1              gun  47.0      M    W               Aloha    OR
# 2          unarmed  23.0      M    H             Wichita    KS
# 3       toy weapon  32.0      M    W       San Francisco    CA
# 4         nail gun  39.0      M    H               Evans    CO
# 5              gun  18.0      M    W             Guthrie    OK
# 6              gun  22.0      M    H            Chandler    AZ
# 7              gun  35.0      M    W             Assaria    KS
# 8          unarmed  34.0      F    W          Burlington    IA
# 9       toy weapon  47.0      M    B           Knoxville    PA
# 10           knife  25.0      M    W            Stockton    CA
# 11             gun  31.0      M    B            Freeport    TX
# 12           knife  41.0      M    B            Columbus    OH
# 13             gun  30.0      M    W          Des Moines    IA
# 14             gun  37.0      M    B         New Orleans    LA
# 15             NaN  28.0      M    W             Huntley    MT
# 16          shovel  42.0      M    W      Salt Lake City    UT
# 17         unarmed  36.0      M    B              Strong    AR
# 18             gun  49.0      M    W            Syracuse    UT
# 19             gun  71.0      M    W             England    AR
# 20             gun  33.0      M    H             El Paso    TX
# 21             gun  39.0      M    W              Arcola    IL
# 22             gun  23.0      M    H          South Gate    CA
# 23             gun  29.0      M    H     North Las Vegas    NV
# 24             gun  34.0      M    W         Albuquerque    NM
# 25           knife  43.0      M    W          Jourdanton    TX
# 26             NaN  24.0      M    B            St. Paul    MN
# 27             NaN  29.0      M    W     Franklin County    MO
# 28             gun  34.0      M    B          Chesapeake    VA
# 29           knife  75.0      M    W          Old Bridge    NJ
# ...            ...   ...    ...  ...                 ...   ...
# 4687           gun   NaN      M    W                 Ona    WV
# 4688         knife   NaN      M  NaN            San Jose    CA
# 4689           gun   NaN      M    A              Fresno    CA
# 4690            ax   NaN      M  NaN           Lancaster    CA
# 4691           gun  34.0      M    W              Bascom    FL
# 4692    toy weapon   NaN      M  NaN            San Jose    CA
# 4693  sharp object  22.0      M    H          Alamogordo    NM
# 4694  undetermined   NaN      M  NaN        Adams County    CO
# 4695  undetermined  41.0      M    H             Orlando    FL
# 4696           gun  38.0      M    H              Odessa    TX
# 4697         sword  29.0      M    W          Vero Beach    FL
# 4698  undetermined  42.0      M    W              Dexter    KY
# 4699         knife  56.0      M  NaN            Parkland    WA
# 4700           gun  32.0      M    B             Phoenix    AZ
# 4701           gun   NaN      M  NaN        Sunland Park    NM
# 4702  sharp object  31.0      M    W            Glendale    AZ
# 4703           gun  21.0      M    H          Las Cruces    NM
# 4704           gun   NaN      M  NaN          Two Rivers    WI
# 4705           gun  48.0      M    B      East Cleveland    OH
# 4706           gun  58.0      M  NaN       Pettis County    MO
# 4707           gun   NaN      M  NaN                Leon    WI
# 4708         knife  45.0      M  NaN              Willis    TX
# 4709           gun  37.0      M    B           Tahlequah    OK
# 4710  undetermined  20.0      M    W           Henryetta    OK
# 4711           gun   NaN      M  NaN         San Antonio    TX
# 4712           gun  31.0      M    B        Fayetteville    NC
# 4713        BB gun  26.0      M  NaN           Wadsworth    OH
# 4714           gun   NaN      M  NaN          Louisville    KY
# 4715           gun  66.0      M  NaN             Conyers    GA
# 4716           gun  37.0      M  NaN  Ashtabula Township    OH
#
#       Signs of Mental Illness  Threat Level     Fleeing?  Body Camera?
# 0                        True        attack  Not fleeing         False
# 1                       False        attack  Not fleeing         False
# 2                       False         other  Not fleeing         False
# 3                        True        attack  Not fleeing         False
# 4                       False        attack  Not fleeing         False
# 5                       False        attack  Not fleeing         False
# 6                       False        attack          Car         False
# 7                       False        attack  Not fleeing         False
# 8                       False         other  Not fleeing          True
# 9                       False        attack  Not fleeing         False
# 10                      False        attack  Not fleeing         False
# 11                      False        attack  Not fleeing         False
# 12                       True         other  Not fleeing         False
# 13                      False        attack          Car         False
# 14                      False        attack         Foot          True
# 15                      False  undetermined  Not fleeing         False
# 16                      False        attack  Not fleeing          True
# 17                      False        attack  Not fleeing         False
# 18                      False        attack  Not fleeing          True
# 19                      False        attack  Not fleeing         False
# 20                      False        attack  Not fleeing         False
# 21                       True        attack  Not fleeing         False
# 22                      False        attack  Not fleeing         False
# 23                      False        attack         Foot         False
# 24                      False        attack         Foot          True
# 25                       True         other  Not fleeing         False
# 26                      False        attack  Not fleeing         False
# 27                      False        attack  Not fleeing         False
# 28                       True        attack  Not fleeing         False
# 29                      False        attack  Not fleeing         False
# ...                       ...           ...          ...           ...
# 4687                    False        attack  Not fleeing         False
# 4688                    False         other  Not fleeing         False
# 4689                    False         other  Not fleeing         False
# 4690                    False         other  Not fleeing         False
# 4691                    False        attack          Car         False
# 4692                    False        attack  Not fleeing         False
# 4693                    False        attack          Car         False
# 4694                    False  undetermined          NaN         False
# 4695                    False        attack  Not fleeing         False
# 4696                    False        attack          Car         False
# 4697                    False        attack  Not fleeing         False
# 4698                    False        attack          NaN         False
# 4699                    False         other  Not fleeing         False
# 4700                    False        attack  Not fleeing         False
# 4701                    False        attack         Foot         False
# 4702                     True        attack  Not fleeing         False
# 4703                    False        attack          NaN         False
# 4704                    False         other  Not fleeing         False
# 4705                    False        attack  Not fleeing          True
# 4706                    False        attack  Not fleeing         False
# 4707                    False         other  Not fleeing         False
# 4708                    False         other          Car         False
# 4709                    False        attack  Not fleeing         False
# 4710                    False  undetermined          NaN         False
# 4711                    False         other          NaN         False
# 4712                    False        attack  Not fleeing         False
# 4713                    False        attack          NaN         False
# 4714                    False        attack          NaN         False
# 4715                    False        attack  Not fleeing         False
# 4716                    False         other  Not fleeing         False
#
# [4677 rows x 14 columns]

# %%
disprop = o.copy()
print(len(disprop))
print(disprop['Race'].value_counts())
# Out:
# 4677
# W    2106
# B    1102
# H     802
# A      79
# N      72
# Name: Race, dtype: int64

# %%
a=dict(disprop['Race'].value_counts())
a=list(a)
b=list(disprop['Race'].value_counts())
print(b)
a=['White','Black','Hispanic','Asian','Native American']
a
# Out:
# [2106, 1102, 802, 79, 72]
# ['White', 'Black', 'Hispanic', 'Asian', 'Native American']

# %%
disprop_per=b[:]
for i in range(len(disprop_per)):
    disprop_per[i]=disprop_per[i]/41.61
disprop_per
# Out:
# [50.612833453496755,
#  26.484018264840184,
#  19.274212929584234,
#  1.8985820716173998,
#  1.7303532804614277]

# %%
def join_lst_and_dic(lst,dic,per):
    new=[]
    for i in range(len(lst)):
        new.append([lst[i], dic[i],per[i]])
    return new
'percent'
kills_by_race_list=join_lst_and_dic(a,b,disprop_per)
kills_by_race = pd.DataFrame(kills_by_race_list)
kills_by_race.columns=['Race','Fatal Police Shootings','Percent']
kills_by_race
# Out:
#               Race  Fatal Police Shootings    Percent
# 0            White                    2106  50.612833
# 1            Black                    1102  26.484018
# 2         Hispanic                     802  19.274213
# 3            Asian                      79   1.898582
# 4  Native American                      72   1.730353

# %%
list(kills_by_race['Percent'])
# Out:
# [50.612833453496755,
#  26.484018264840184,
#  19.274212929584234,
#  1.8985820716173998,
#  1.7303532804614277]

# %%
us={'Race':['White','Black','Hispanic','Asian','Native American'], 'Percent': [60.4, 13.4, 18.3, 5.9,1.3]}
us = pd.DataFrame(us)
us
# Out:
#               Race  Percent
# 0            White     60.4
# 1            Black     13.4
# 2         Hispanic     18.3
# 3            Asian      5.9
# 4  Native American      1.3

# %%
kills_by_race.plot.bar(x='Race',y='Percent')
us.plot.bar(x='Race',y='Percent')

# %%
data = [[50.612833453496755,
 26.484018264840184,
 19.274212929584234,
 1.8985820716173998,
 1.7303532804614277]] 
Shootings_by_Race_df= pd.DataFrame(data, columns = ['White','Black','Hispanic','Asian','Native American'])
data2 = [[60.4, 13.4, 18.3, 5.9,1.3]]
US_Race_Proportions_df= pd.DataFrame(data2, columns = ['White','Black','Hispanic','Asian','Native American'])
Shootings_by_Race_df.rename(index = {0:'# of Fatal Police Shootings By Race'}, inplace = True) 
US_Race_Proportions_df.rename(index = {0:'U.S. Population Proportions By Race'}, inplace = True)

# %%
Shootings_by_Race = Shootings_by_Race_df.plot(kind='barh', stacked=True, zorder=2, width=0.25)

  # Despine
Shootings_by_Race.spines['right'].set_visible(False)
Shootings_by_Race.spines['top'].set_visible(False)
Shootings_by_Race.spines['left'].set_visible(False)
Shootings_by_Race.spines['bottom'].set_visible(False)

#Shootings_by_Race.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = Shootings_by_Race.get_xticks()
for tick in vals:
      Shootings_by_Race.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)
  # Set x-axis label
Shootings_by_Race.set_xlabel("Percent", labelpad=20, size=12)
Shootings_by_Race.set_title('Share of Fatal Police Shootings by Race')
###

US_Race_Proportions = US_Race_Proportions_df.plot(kind='barh', stacked=True, zorder=2, width=0.25)

  # Despine
US_Race_Proportions.spines['right'].set_visible(False)
US_Race_Proportions.spines['top'].set_visible(False)
US_Race_Proportions.spines['left'].set_visible(False)
US_Race_Proportions.spines['bottom'].set_visible(False)

#Shootings_by_Race.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = US_Race_Proportions.get_xticks()
for tick in vals:
      US_Race_Proportions.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)
  # Set x-axis label
US_Race_Proportions.set_xlabel("Percent", labelpad=20, size=12)
US_Race_Proportions.set_title('Share of US Population by Race')
# Out:
# Text(0.5, 1.0, 'Share of US Population by Race')

# %%
gender_df = pd.DataFrame(police['Gender'].value_counts())
gender = gender_df.plot(kind='barh',zorder=2)
gender.spines['right'].set_visible(False)
gender.spines['top'].set_visible(False)
gender.spines['left'].set_visible(False)
gender.spines['bottom'].set_visible(False)

#Shootings_by_Race.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = gender.get_xticks()
for tick in vals:
      gender.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)
  # Set x-axis label
#gender.set_xlabel("Percent", labelpad=20, size=12)
gender.get_legend().remove()
gender.set_title('Victim Gender')
for i, v in enumerate(gender_df['Gender']):
    gender.text(v + 100, i, str(v))

# %%
flee_df = pd.DataFrame(police['Fleeing?'].value_counts())

flee = flee_df.plot(kind='barh',zorder=2)
flee.spines['right'].set_visible(False)
flee.spines['top'].set_visible(False)
flee.spines['left'].set_visible(False)
flee.spines['bottom'].set_visible(False)

#Shootings_by_Race.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = flee.get_xticks()
for tick in vals:
      flee.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)
  # Set x-axis label
#flee.set_xlabel("Percent", labelpad=20, size=12)
flee.get_legend().remove()
flee.set_title('Were they Fleeing?')
# Out:
# Text(0.5, 1.0, 'Were they Fleeing?')

# %%
threat_df = pd.DataFrame(police['Threat Level'].value_counts())

threat = threat_df.plot(kind='barh',zorder=2)
threat.spines['right'].set_visible(False)
threat.spines['top'].set_visible(False)
threat.spines['left'].set_visible(False)
threat.spines['bottom'].set_visible(False)

#Shootings_by_Race.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = threat.get_xticks()
for tick in vals:
      threat.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)
  # Set x-axis label
#threat.set_xlabel("Percent", labelpad=20, size=12)
threat.get_legend().remove()
threat.set_title('Was the Officer Being Attacked?')
# Out:
# Text(0.5, 1.0, 'Was the Officer Being Attacked?')

# %%
body_camera_df = pd.DataFrame(police['Body Camera?'].value_counts())

body_camera = body_camera_df.plot(kind='barh',zorder=2)
body_camera.spines['right'].set_visible(False)
body_camera.spines['top'].set_visible(False)
body_camera.spines['left'].set_visible(False)
body_camera.spines['bottom'].set_visible(False)

#Shootings_by_Race.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = body_camera.get_xticks()
for tick in vals:
      body_camera.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)
  # Set x-axis label
body_camera.set_xlabel("Percent", labelpad=20, size=12)
body_camera.get_legend().remove()
body_camera.set_title('Prescence of Working Body Camera?')
for i, v in enumerate(body_camera_df['Body Camera?']):
    body_camera.text(v + 100,i , str(v))

# %%
q = list(dict(police['Armed?'].value_counts()))
w = list(police['Armed?'].value_counts())
arm_lst=[]
for i in range(len(q)):
    arm_lst.append([q[i],w[i]])
arm_lst
# Out:
# [['gun', 2621],
#  ['knife', 696],
#  ['unarmed', 295],
#  ['undetermined', 198],
#  ['toy weapon', 163],
#  ['vehicle', 89],
#  ['unknown weapon', 61],
#  ['machete', 40],
#  ['ax', 24],
#  ['Taser', 19],
#  ['sword', 17],
#  ['gun and knife', 16],
#  ['baseball bat', 15],
#  ['hammer', 13],
#  ['metal pipe', 11],
#  ['box cutter', 10],
#  ['hatchet', 10],
#  ['sharp object', 9],
#  ['screwdriver', 9],
#  ['crossbow', 9],
#  ['gun and car', 8],
#  ['pipe', 6],
#  ['blunt object', 5],
#  ['piece of wood', 5],
#  ['baton', 5],
#  ['scissors', 5],
#  ['shovel', 4],
#  ['metal object', 4],
#  ['rock', 4],
#  ['gun and vehicle', 4],
#  ['BB gun', 4],
#  ['crowbar', 4],
#  ['guns and explosives', 3],
#  ['metal stick', 3],
#  ['meat cleaver', 3],
#  ['beer bottle', 3],
#  ['pick-axe', 3],
#  ['pellet gun', 3],
#  ['straight edge razor', 3],
#  ['chair', 3],
#  ['glass shard', 3],
#  ['brick', 2],
#  ['incendiary device', 2],
#  ['pole and knife', 2],
#  ['garden tool', 2],
#  ['hatchet and gun', 2],
#  ['pole', 2],
#  ['lawn mower blade', 2],
#  ['pitchfork', 2],
#  ['chain', 2],
#  ['chain saw', 2],
#  ['metal pole', 2],
#  ['Airsoft pistol', 1],
#  ['walking stick', 1],
#  ['fireworks', 1],
#  ['baseball bat and bottle', 1],
#  ['BB gun and vehicle', 1],
#  ['carjack', 1],
#  ['flashlight', 1],
#  ["contractor's level", 1],
#  ['stapler', 1],
#  ['flagpole', 1],
#  ['machete and gun', 1],
#  ['tire iron', 1],
#  ['motorcycle', 1],
#  ['gun and sword', 1],
#  ['bow and arrow', 1],
#  ['pen', 1],
#  ['air conditioner', 1],
#  ['chainsaw', 1],
#  ['pepper spray', 1],
#  ['barstool', 1],
#  ['spear', 1],
#  ['claimed to be armed', 1],
#  ['cordless drill', 1],
#  ['bean-bag gun', 1],
#  ['metal hand tool', 1],
#  ['vehicle and gun', 1],
#  ['oar', 1],
#  ['wrench', 1],
#  ['air pistol', 1],
#  ['wasp spray', 1],
#  ['samurai sword', 1],
#  ['metal rake', 1],
#  ['nail gun', 1],
#  ['bayonet', 1],
#  ['hand torch', 1],
#  ['baseball bat and fireplace poker', 1]]

# %%
arm_df=pd.DataFrame(police['Armed?'].value_counts())
arm_df
# Out:
#                                   Armed?
# gun                                 2621
# knife                                696
# unarmed                              295
# undetermined                         198
# toy weapon                           163
# vehicle                               89
# unknown weapon                        61
# machete                               40
# ax                                    24
# Taser                                 19
# sword                                 17
# gun and knife                         16
# baseball bat                          15
# hammer                                13
# metal pipe                            11
# box cutter                            10
# hatchet                               10
# sharp object                           9
# screwdriver                            9
# crossbow                               9
# gun and car                            8
# pipe                                   6
# blunt object                           5
# piece of wood                          5
# baton                                  5
# scissors                               5
# shovel                                 4
# metal object                           4
# rock                                   4
# gun and vehicle                        4
# ...                                  ...
# flashlight                             1
# contractor's level                     1
# stapler                                1
# flagpole                               1
# machete and gun                        1
# tire iron                              1
# motorcycle                             1
# gun and sword                          1
# bow and arrow                          1
# pen                                    1
# air conditioner                        1
# chainsaw                               1
# pepper spray                           1
# barstool                               1
# spear                                  1
# claimed to be armed                    1
# cordless drill                         1
# bean-bag gun                           1
# metal hand tool                        1
# vehicle and gun                        1
# oar                                    1
# wrench                                 1
# air pistol                             1
# wasp spray                             1
# samurai sword                          1
# metal rake                             1
# nail gun                               1
# bayonet                                1
# hand torch                             1
# baseball bat and fireplace poker       1
#
# [88 rows x 1 columns]

# %%
drop_these = arm_df[arm_df['Armed?'] < 62 ].index
arm_df.drop(drop_these , inplace=True)
arm_df
# Out:
#               Armed?
# gun             2621
# knife            696
# unarmed          295
# undetermined     198
# toy weapon       163
# vehicle           89

# %%
arm_df.loc[6]=655
arm_df=arm_df.rename(index={'gun': 'Gun','knife':'Knife', 'unarmed':'Unarmed', 'undetermined':'Undetermined', 'toy weapon':'Toy Weapon', 'vehicle':'Vehicle',6:'Misc.'})
arm_df
# Out:
#               Armed?
# Gun             2621
# Knife            696
# Unarmed          295
# Undetermined     198
# Toy Weapon       163
# Vehicle           89
# Misc.            655

# %%
arm = arm_df.plot(kind='barh',zorder=2)
arm.spines['right'].set_visible(False)
arm.spines['top'].set_visible(False)
arm.spines['left'].set_visible(False)
arm.spines['bottom'].set_visible(False)

#Shootings_by_Race.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = arm.get_xticks()
for tick in vals:
      arm.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)
arm.get_legend().remove()
for i, v in enumerate(arm_df['Armed?']):
    arm.text(v + 50,i - .1, str(v))

# %%
arm = arm_df.plot(kind='bar', zorder=2)
'''body_camera.spines['right'].set_visible(False)
body_camera.spines['top'].set_visible(False)
body_camera.spines['left'].set_visible(False)
body_camera.spines['bottom'].set_visible(False)

#Shootings_by_Race.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = body_camera.get_xticks()
for tick in vals:
      body_camera.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)
  # Set x-axis label
body_camera.set_xlabel("Percent", labelpad=20, size=12)
body_camera.get_legend().remove()'''
# Out:
# 'body_camera.spines[\'right\'].set_visible(False)\nbody_camera.spines[\'top\'].set_visible(False)\nbody_camera.spines[\'left\'].set_visible(False)\nbody_camera.spines[\'bottom\'].set_visible(False)\n\n#Shootings_by_Race.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")\n\n  # Draw vertical axis lines\nvals = body_camera.get_xticks()\nfor tick in vals:\n      body_camera.axvline(x=tick, linestyle=\'dashed\', alpha=0.4, color=\'#eeeeee\', zorder=1)\n  # Set x-axis label\nbody_camera.set_xlabel("Percent", labelpad=20, size=12)\nbody_camera.get_legend().remove()'

# %%
'''
    Women vs men, armed , flee , threat_level, body_camera
    signs_of_mental_illness-combine w/ race?
    bar graphs of race and:
        armed?
        mental illness
        flee
    reg:
        edu lvl and 
        
   
   
   
   
   
'''
# Out:
# '\n    Women vs men, armed , flee , threat_level, body_camera\n    signs_of_mental_illness-combine w/ race?\n    bar graphs of race and:\n        armed?\n        mental illness\n        flee\n    reg:\n        edu lvl and \n        \n   \n   \n   \n   \n   \n'
